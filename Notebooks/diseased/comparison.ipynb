# %%
import numpy as np

# %%
dir_path = "/Users/ecem/Documents/GitHub/seismocardiogram/data/diseased-dataset/Raw_Recordings"
other = "/Users/ecem/Downloads"

# %%
x_new  = np.load(dir_path + "/tr_x.npy", allow_pickle= True)
x_or = np.load(other + "/tr_x.npy", allow_pickle= True)

# %%
for i in range(0,100):
    print(i)
    print(x_new[i])
    print(x_or[i])
# Out:
# 0
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:08:07.640625Z | 256.0 Hz, 124837 samples
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:08:07.640625Z | 256.0 Hz, 124837 samples
# 1
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:09:57.117188Z | 256.0 Hz, 152863 samples
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:09:57.117188Z | 256.0 Hz, 152863 samples
# 2
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:09:56.785156Z | 256.0 Hz, 152778 samples
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:09:56.785156Z | 256.0 Hz, 152778 samples
# 3
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:08:56.687500Z | 256.0 Hz, 137393 samples
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:08:56.687500Z | 256.0 Hz, 137393 samples
# 4
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:07:56.722656Z | 256.0 Hz, 122042 samples
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:07:56.722656Z | 256.0 Hz, 122042 samples
# 5
# ...
