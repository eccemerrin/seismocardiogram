# %%
import pandas as pd  
import numpy as np 
import seaborn as sns  
import matplotlib.pyplot as plt  
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import plot_confusion_matrix
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
heart = pd.read_excel("/Users/ecem/Documents/GitHub/seismocardiogram/data/diseased-dataset/Summary_Pub_Deidentified.xlsx")
df = heart.copy()

# %%
df.drop(["Mitral valve Peak velocity (m/sec)",
         "Mitral valve Mean gradient(mmHg)", 
         "Echo available",
        "Date of collection",
        "Date of echo"], 
        inplace = True, axis = 1)
df.drop(df.tail(1).index,inplace=True)

# %%
df.head(5)
# Out:
#   Patient ID     Start  Duration  Sampling rate(Hz)   Age Gender  Height (cm)  \
# 0      CP-01  00:00:08  00:07:42              256.0  59.0      M        174.0
# 1      CP-02  00:00:45  00:08:20              256.0  73.0      M        162.0
# 2      CP-03  00:00:40  00:08:50              256.0  70.0      M        167.0
# 3      CP-04  00:00:02  00:08:30              256.0  56.0      M        154.0
# 4      CP-05  00:00:50  00:07:00              256.0  59.0      M        163.0
#
#    Weight (kg)  History of MI  History of CABG  ...  TAPSE  \
# 0         74.0            0.0              0.0  ...   19.0
# 1         63.0            0.0              0.0  ...   19.0
# 2         84.0            0.0              0.0  ...   20.0
# 3         56.0            0.0              0.0  ...   17.0
# 4         55.0            0.0              0.0  ...   17.0
#
#    Aortic valve area (cm2)  Aortic valve area Mean gradient(mmHg)  \
# 0                      NaN                                    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 31 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Patient ID                                     100 non-null    object
#  1   Start                                          100 non-null    object
#  2   Duration                                       100 non-null    object
#  3   Sampling rate(Hz)                              100 non-null    float64
#  4   Age                                            100 non-null    float64
#  5   Gender                                         100 non-null    object
#  6   Height (cm)                                    100 non-null    float64
#  7   Weight (kg)                                    100 non-null    float64
#  8   History of MI                                  100 non-null    float64
# ...

# %%
df.isnull().sum() #to check "null" values
# Out:
# Patient ID                                        0
# Start                                             0
# Duration                                          0
# Sampling rate(Hz)                                 0
# Age                                               0
# Gender                                            0
# Height (cm)                                       0
# Weight (kg)                                       0
# History of MI                                     0
# History of CABG                                   0
# History of PCI                                    0
# AOD (mm)                                         30
# LAD (mm)                                         30
# LVDs                                             30
# Ejection fraction (%)                             0
# Left ventricular end diastolic dimension (mm)     0
# IVS (mm)                                          0
# LVPW (mm)                                         0
# ...

# %%
df.fillna(0)
# Out:
#    Patient ID     Start  Duration  Sampling rate(Hz)   Age Gender  \
# 0       CP-01  00:00:08  00:07:42         256.000000  59.0      M
# 1       CP-02  00:00:45  00:08:20         256.000000  73.0      M
# 2       CP-03  00:00:40  00:08:50         256.000000  70.0      M
# 3       CP-04  00:00:02  00:08:30         256.000000  56.0      M
# 4       CP-05  00:00:50  00:07:00         256.000000  59.0      M
# ..        ...       ...       ...                ...   ...    ...
# 95      UP-26  00:00:00  00:05:08         512.166667  80.0      M
# 96      UP-27  00:00:00  00:05:05         512.208333  82.0      M
# 97      UP-28  00:00:00  00:05:02         512.250000  71.0      M
# 98      UP-29  00:00:00  00:04:58         512.291667  80.0      M
# 99      UP-30  00:00:00  00:04:59         512.333333  71.0      M
#
#     Height (cm)  Weight (kg)  History of MI  History of CABG  ...  TAPSE  \
# 0         174.0         74.0            0.0              0.0  ...   19.0
# ...

# %%
df.describe().T
# Out:
#                                                count        mean        std  \
# Sampling rate(Hz)                              100.0  279.055000  73.679558
# Age                                            100.0   67.740000  14.493203
# Height (cm)                                    100.0  164.868000   9.468319
# Weight (kg)                                    100.0   68.505000  13.127759
# History of MI                                  100.0    0.050000   0.219043
# History of CABG                                100.0    0.210000   0.409360
# History of PCI                                 100.0    0.240000   0.429235
# AOD (mm)                                        70.0   29.557143   4.461220
# LAD (mm)                                        70.0   48.757143   9.004726
# LVDs                                            70.0   39.271429   9.486713
# Ejection fraction (%)                          100.0   56.815000  11.646540
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(40,40)
sns.heatmap(df.corr(), square = True, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot( x = df["Age"],
             hist = True,
             bins = 10,
             kde = True,
             vertical = False, color = "y").set(title = "age density");
# Out:
# /Users/ecem/miniforge3/envs/tf-metal/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.lmplot(x = "Age", y = "Aortic valve area (cm2)", data = df)

# %%
sns.lmplot(x = "Age", y = "TAPSE", data = df)

# %%
sns.catplot(x = "AOD (mm)", y = "LAD (mm)", data = df  )

# %%
sns.catplot(x = "AOD (mm)", y = "Ejection fraction (%)", data = df )
