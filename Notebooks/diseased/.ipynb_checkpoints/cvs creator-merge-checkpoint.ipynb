# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
dir_path = "/Users/ecem/Documents/GitHub/seismocardiogram/data/diseased-dataset/Raw_Recordings"

# %%
wavelet = pd.read_csv(dir_path + '/wavelet_coef.csv', index_col = 0)
spectogram = pd.read_csv(dir_path + '/spectogram_coef.csv', index_col = 0)
signal_processing = pd.read_csv(dir_path + '/signal_processing.csv', index_col = 0)

# %%
wavelet
# Out:
#         lvl_x1    lvl_x2    lvl_x3    lvl_x4    lvl_x5    lvl_x6    lvl_x7  \
# 0    -0.345541 -0.004215  0.012522 -0.000444  0.001311  0.000406 -0.000041
# 1    -0.273343  0.000739 -0.003220 -0.001112 -0.001604 -0.000032  0.000201
# 2    -0.263624  0.000413 -0.005284 -0.001486 -0.000138 -0.000489  0.000041
# 3    -0.341478 -0.004371  0.014861  0.007202  0.000489  0.000580  0.000105
# 4    -0.343430 -0.002166 -0.007141 -0.002059 -0.000725 -0.000040  0.000090
# ...        ...       ...       ...       ...       ...       ...       ...
# 1457  0.016465  0.002972 -0.001682  0.000326 -0.000033 -0.000025 -0.000110
# 1458 -0.087744 -0.001489 -0.002959 -0.001529 -0.000229 -0.000535 -0.000055
# 1459 -0.077756 -0.001602  0.001775  0.000274  0.000203 -0.000447 -0.000076
# 1460 -0.045109  0.001392 -0.000355 -0.000908  0.000429  0.000397 -0.000011
# 1461  0.006173 -0.001153  0.000650  0.000231  0.000123 -0.000199 -0.000032
#
# ...

# %%
spectogram
# Out:
#        freq_x0   freq_y0   freq_z0   freq_x1   freq_y1   freq_z1   freq_x2  \
# 0     0.000462  0.000658  0.000667  0.000676  0.000683  0.000685  0.000687
# 1     0.000359  0.000513  0.000522  0.000531  0.000538  0.000542  0.000546
# 2     0.000467  0.000674  0.000698  0.000725  0.000752  0.000779  0.000804
# 3     0.000422  0.000606  0.000621  0.000636  0.000647  0.000654  0.000656
# 4     0.000379  0.000540  0.000547  0.000553  0.000556  0.000557  0.000559
# ...        ...       ...       ...       ...       ...       ...       ...
# 1457  0.000403  0.000578  0.000591  0.000604  0.000617  0.000630  0.000643
# 1458  0.000512  0.000735  0.000751  0.000764  0.000772  0.000775  0.000775
# 1459  0.000596  0.000844  0.000843  0.000836  0.000823  0.000803  0.000778
# 1460  0.000465  0.000663  0.000672  0.000678  0.000682  0.000682  0.000685
# 1461  0.000366  0.000522  0.000532  0.000542  0.000552  0.000562  0.000574
#
# ...

# %%
signal_processing
# Out:
#         zcr_x0    zcr_y0    zcr_z0    zcr_x1    zcr_y1    zcr_z1  zcr_x2  \
# 0     0.014648  0.027344  0.041016  0.058594  0.048828  0.036133   131.0
# 1     0.049805  0.071289  0.089844  0.088867  0.063477  0.041992   233.0
# 2     0.033203  0.047852  0.065430  0.060547  0.046875  0.032227   165.0
# 3     0.024414  0.040527  0.049805  0.041016  0.029297  0.012695   111.0
# 4     0.018066  0.035156  0.052734  0.069824  0.059570  0.042969   161.0
# ...        ...       ...       ...       ...       ...       ...     ...
# 1457  0.003906  0.003906  0.006836  0.006836  0.003906  0.003906    17.0
# 1458  0.010742  0.013672  0.016602  0.014648  0.005859  0.002930    35.0
# 1459  0.004883  0.028320  0.064941  0.104492  0.101562  0.078125   219.0
# 1460  0.065918  0.103027  0.142578  0.156250  0.122559  0.085938   388.0
# 1461  0.058105  0.083496  0.125488  0.119141  0.096680  0.071289   318.0
#
#         zcr_y2    zcr_z2    zcr_x3  ...  tempogram_x381  tempogram_y381  \
# ...

# %%
df = pd.concat([wavelet.drop(['disease'], axis =1), spectogram.drop(['disease'], axis =1)], axis=1)
df = pd.concat([df, signal_processing], axis=1)

# %%
df
# Out:
#         lvl_x1    lvl_x2    lvl_x3    lvl_x4    lvl_x5    lvl_x6    lvl_x7  \
# 0    -0.345541 -0.004215  0.012522 -0.000444  0.001311  0.000406 -0.000041
# 1    -0.273343  0.000739 -0.003220 -0.001112 -0.001604 -0.000032  0.000201
# 2    -0.263624  0.000413 -0.005284 -0.001486 -0.000138 -0.000489  0.000041
# 3    -0.341478 -0.004371  0.014861  0.007202  0.000489  0.000580  0.000105
# 4    -0.343430 -0.002166 -0.007141 -0.002059 -0.000725 -0.000040  0.000090
# ...        ...       ...       ...       ...       ...       ...       ...
# 1457  0.016465  0.002972 -0.001682  0.000326 -0.000033 -0.000025 -0.000110
# 1458 -0.087744 -0.001489 -0.002959 -0.001529 -0.000229 -0.000535 -0.000055
# 1459 -0.077756 -0.001602  0.001775  0.000274  0.000203 -0.000447 -0.000076
# 1460 -0.045109  0.001392 -0.000355 -0.000908  0.000429  0.000397 -0.000011
# 1461  0.006173 -0.001153  0.000650  0.000231  0.000123 -0.000199 -0.000032
#
# ...

# %%
df.to_csv(dir_path + '/final_features.csv')
