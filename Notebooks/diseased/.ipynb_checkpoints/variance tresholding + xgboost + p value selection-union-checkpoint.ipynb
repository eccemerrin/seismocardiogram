# %% [markdown]
# ### features:
# * selected spectogram coef
# * zero crossing rate
# * selected chromogram values
# * tempogram
# * wavelet of level 0

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import auc
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve, recall_score
import matplotlib.pyplot as plt
from yellowbrick.classifier import ClassBalance, ROCAUC, ClassificationReport, ClassPredictionError
import itertools
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
csv_path = "/Users/ecem/Desktop/csv of scgs"
wavelet_csv = "/Users/ecem/Desktop/wavelet-csv"

# %% [markdown]
# ## Load data

# %% [markdown]
# Here, our target is to predict disease correctly. So; our y will be disease column of  dataset

# %%
spec = pd.read_csv(csv_path + '/p-value-selected-spec.csv', index_col = 0)
#spec  #uncomment to see dataframe

signal_proc = pd.read_csv(csv_path + '/signal_processing.csv', index_col = 0)
y = signal_proc.disease

zero_crossing = signal_proc.iloc[:,:21]
#zero_crossing #uncomment to see dataframe

tempogram = signal_proc.iloc[:, -1153: ].drop(['disease'], axis =1)
#tempogram #uncomment to see dataframe

chromogram = pd.read_csv(csv_path + '/p-value-selected-chromogram.csv', index_col = 0)
#chromogram #uncomment to see dataframe

w_lvl0 = pd.read_csv(wavelet_csv + '/wavelet_lvl0.csv', index_col = 0).drop(['disease'], axis =1)
#w_lvl0  #uncomment to see dataframe

# %%
#tempogram

# %%
features = pd.concat([spec, w_lvl0], axis = 1)
features = pd.concat([features, zero_crossing], axis = 1)
features = pd.concat([features, chromogram], axis = 1)
features = pd.concat([features, tempogram], axis = 1)

features
# Out:
#        freq_z6   freq_x7   freq_y7   freq_z7   freq_x8  freq_y33  freq_z33  \
# 0     0.000537  0.000510  0.000486  0.000469  0.000462  0.000614  0.000613
# 1     0.000682  0.000677  0.000674  0.000672  0.000674  0.000779  0.000775
# 2     0.000641  0.000614  0.000593  0.000581  0.000579  0.000573  0.000574
# 3     0.000680  0.000669  0.000650  0.000626  0.000602  0.000578  0.000590
# 4     0.000597  0.000572  0.000545  0.000516  0.000487  0.000473  0.000489
# ...        ...       ...       ...       ...       ...       ...       ...
# 1457  0.000792  0.000804  0.000812  0.000812  0.000805  0.000744  0.000774
# 1458  0.000748  0.000725  0.000702  0.000678  0.000655  0.000625  0.000660
# 1459  0.000552  0.000548  0.000541  0.000532  0.000522  0.000616  0.000629
# 1460  0.000776  0.000790  0.000800  0.000804  0.000802  0.000817  0.000804
# 1461  0.000654  0.000646  0.000641  0.000635  0.000629  0.000521  0.000552
#
#       freq_x34  freq_y34  freq_z34  ...  tempogram_z380  tempogram_x381  \
# 0     0.000613  0.000616  0.000625  ...   -5.561703e-17    8.170721e-17
# 1     0.000770  0.000767  0.000765  ...   -3.762791e-17    9.230623e-17
# 2     0.000576  0.000577  0.000584  ...   -4.190613e-17    1.327003e-16
# 3     0.000602  0.000611  0.000619  ...   -6.435142e-17    9.178333e-17
# 4     0.000503  0.000514  0.000520  ...   -8.023680e-17    1.020862e-16
# ...        ...       ...       ...  ...             ...             ...
# 1457  0.000807  0.000842  0.000875  ...   -6.989953e-17    1.092569e-16
# 1458  0.000688  0.000708  0.000720  ...   -7.604840e-17    1.279276e-16
# 1459  0.000637  0.000638  0.000636  ...   -1.002924e-16    1.573167e-16
# 1460  0.000781  0.000748  0.000710  ...   -4.295499e-17    1.618298e-16
# 1461  0.000588  0.000625  0.000657  ...   -3.094960e-17    1.112771e-16
#
#       tempogram_y381  tempogram_z381  tempogram_x382  tempogram_y382  \
# 0      -2.901693e-17    7.136817e-18   -1.600198e-18   -1.820086e-17
# 1      -4.144594e-18    3.134702e-17    3.936268e-17   -1.225676e-17
# 2      -2.377157e-17    6.366701e-17    3.959152e-17   -4.856586e-18
# 3      -5.410009e-17    2.972298e-17    1.549096e-18   -2.242585e-17
# 4      -5.450610e-17    3.300947e-17    2.042482e-17   -3.054250e-17
# ...              ...             ...             ...             ...
# 1457   -3.965254e-17    3.359798e-17    3.128191e-17   -1.650984e-17
# 1458   -2.994918e-17    8.031802e-17    2.583045e-17   -5.585955e-18
# 1459   -9.061621e-17    6.145682e-17   -1.830133e-18   -9.797867e-18
# 1460   -3.892819e-17    7.816536e-17    9.146981e-17   -9.973236e-18
# 1461   -2.378647e-17    5.724459e-17    8.041083e-17   -1.556972e-17
#
#       tempogram_z382  tempogram_x383  tempogram_y383  tempogram_z383
# 0       5.445167e-17   -3.617391e-18    1.311147e-17    1.583380e-17
# 1       7.197155e-17    1.164168e-17    4.208469e-17    2.315461e-17
# 2       8.395845e-17    2.796561e-17    4.234865e-17    5.989837e-17
# 3       3.681072e-17    9.680305e-18    4.201538e-18    3.254941e-17
# 4       3.431347e-17    7.431554e-18   -2.569287e-18    1.355442e-17
# ...              ...             ...             ...             ...
# 1457    7.995795e-17   -1.191038e-17    1.213728e-17    1.655357e-17
# 1458    8.586355e-17    9.897430e-18    3.305590e-17    4.198648e-17
# 1459    4.984540e-17    3.377098e-18    1.044522e-17    6.453195e-17
# 1460    1.190564e-16    6.819272e-19    6.840075e-17    4.218233e-17
# 1461    9.494301e-17   -9.698190e-19    4.565146e-17    5.232184e-17
#
# [1462 rows x 4871 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_encoded
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
list(le.classes_)
# Out:
# ['AR', 'AS', 'MR', 'MS']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(features, y_encoded, train_size=0.8, test_size=0.2,
                                                                random_state=42)

# %%
import xgboost as xgb
model  = xgb.XGBClassifier(random_state = 42, objective='multi:softprob', eval_metric = 'merror') 

# Fit the model
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='merror', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=42, reg_alpha=0, ...)

# %%
predictions = model.predict(X_valid)

# %%
classes = ['AR', 'AS', 'MR', 'MS']

# %%
rocauc = ROCAUC(model, size=(1000, 700), classes=classes)

rocauc.fit(X_train, y_train)       
rocauc.score(X_valid, y_valid)  
r = rocauc.poof()

# %%
report = ClassificationReport(model, size=(1080, 720), classes=classes)

report.score(X_valid, y_valid)
c = report.poof()
# Out:
# /Users/ecem/miniforge3/envs/tf-metal/lib/python3.9/site-packages/yellowbrick/classifier/base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_valid, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

recall = recall_score(y_valid, predictions, average= 'weighted')
print("recall: %.2f%%" % (recall * 100.0))

from sklearn.metrics import precision_score
precision = precision_score(y_valid, predictions, average= 'weighted')
print("precision: %.2f%%" % (precision * 100.0))
# Out:
# Accuracy: 86.01%
# recall: 86.01%
# precision: 86.97%

# %% [markdown]
# ### with 0.01 variation

# %%
vt = VarianceThreshold(threshold = 0.0001)

# %%
_ = vt.fit(features)
masked = vt.get_support()
features_masked = features.loc[:, masked]
features_masked # uncomment to see the dataframe
# Out:
#       freq_x563  freq_y563  freq_z563  freq_x564  freq_y564  freq_z564  \
# 0      0.001880   0.001847   0.001862   0.001916   0.001992   0.002066
# 1      0.002336   0.002379   0.002457   0.002558   0.002656   0.002732
# 2      0.002529   0.002579   0.002619   0.002633   0.002617   0.002569
# 3      0.002740   0.002799   0.002833   0.002833   0.002798   0.002727
# 4      0.002170   0.002145   0.002131   0.002139   0.002177   0.002221
# ...         ...        ...        ...        ...        ...        ...
# 1457   0.001752   0.001815   0.001869   0.001918   0.001966   0.002007
# 1458   0.002414   0.002425   0.002417   0.002395   0.002374   0.002373
# 1459   0.002127   0.002121   0.002115   0.002108   0.002103   0.002109
# 1460   0.001754   0.001852   0.001950   0.002046   0.002131   0.002195
# 1461   0.002403   0.002354   0.002318   0.002301   0.002306   0.002318
#
#       freq_x565  freq_y565  freq_z565  freq_x566  ...  tempogram_z291  \
# 0      0.002122   0.002156   0.002167   0.002159  ...        0.050637
# 1      0.002776   0.002786   0.002764   0.002737  ...        0.054045
# 2      0.002496   0.002410   0.002321   0.002236  ...        0.062990
# 3      0.002626   0.002506   0.002391   0.002308  ...        0.053937
# 4      0.002270   0.002317   0.002355   0.002381  ...        0.060121
# ...         ...        ...        ...        ...  ...             ...
# 1457   0.002036   0.002050   0.002050   0.002055  ...        0.064962
# 1458   0.002395   0.002433   0.002475   0.002517  ...        0.074385
# 1459   0.002116   0.002130   0.002158   0.002207  ...        0.082742
# 1460   0.002233   0.002242   0.002224   0.002184  ...        0.078625
# 1461   0.002339   0.002383   0.002447   0.002511  ...        0.059267
#
#       tempogram_x292  tempogram_y292  tempogram_z292  tempogram_x293  \
# 0           0.048737        0.046883        0.045077        0.043317
# 1           0.051993        0.049993        0.048044        0.046145
# 2           0.060546        0.058165        0.055847        0.053592
# 3           0.051892        0.049899        0.047957        0.046065
# 4           0.057816        0.055570        0.053382        0.051252
# ...              ...             ...             ...             ...
# 1457        0.062435        0.059975        0.057579        0.055248
# 1458        0.071438        0.068570        0.065780        0.063067
# 1459        0.079374        0.076100        0.072918        0.069827
# 1460        0.075380        0.072226        0.069163        0.066189
# 1461        0.056979        0.054749        0.052579        0.050466
#
#       tempogram_y293  tempogram_z293  tempogram_x294  tempogram_y294  \
# 0           0.041602        0.039933        0.038309        0.036729
# 1           0.044297        0.042499        0.040750        0.039050
# 2           0.051399        0.049266        0.047194        0.045181
# 3           0.044223        0.042431        0.040687        0.038992
# 4           0.049179        0.047162        0.045202        0.043297
# ...              ...             ...             ...             ...
# 1457        0.052982        0.050778        0.048637        0.046557
# 1458        0.060430        0.057868        0.055381        0.052968
# 1459        0.066826        0.063914        0.061089        0.058351
# 1460        0.063304        0.060505        0.057792        0.055164
# 1461        0.048411        0.046412        0.044470        0.042583
#
#       tempogram_z294
# 0           0.035193
# 1           0.037398
# 2           0.043227
# 3           0.037345
# 4           0.041447
# ...              ...
# 1457        0.044539
# 1458        0.050627
# 1459        0.055698
# 1460        0.052619
# 1461        0.040751
#
# [1462 rows x 1494 columns]

# %%
X_train_, X_valid_, y_train_, y_valid_ = train_test_split(features_masked, y_encoded, train_size=0.8, test_size=0.2,
                                                                random_state=42)

# %%
import xgboost as xgb
model_  = xgb.XGBClassifier(random_state = 42, eval_metric = 'merror', objective='multi:softprob' ) 

# Fit the model
model_.fit(X_train_, y_train_)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='merror', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=42, reg_alpha=0, ...)

# %%
predictions_ = model_.predict(X_valid_)

# %%
rocauc_ = ROCAUC(model_, size=(1000, 700), classes=classes)

rocauc_.fit(X_train_, y_train_)       
rocauc_.score(X_valid_, y_valid_)  
r = rocauc_.poof()

# %%
report_ = ClassificationReport(model_, size=(1080, 720), classes=classes)

report_.score(X_valid_, y_valid_)
c = report_.poof()
# Out:
# /Users/ecem/miniforge3/envs/tf-metal/lib/python3.9/site-packages/yellowbrick/classifier/base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_valid_, predictions_)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 88.74%

# %%
recall = recall_score(y_valid_, predictions_, average= 'weighted')
print("recall: %.2f%%" % (recall * 100.0))

from sklearn.metrics import precision_score
precision = precision_score(y_valid_, predictions_, average= 'weighted')
print("precision: %.2f%%" % (precision * 100.0))
# Out:
# recall: 88.74%
# precision: 89.03%

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model, X_valid, y_valid)  
plt.show()
# Out:
# /Users/ecem/miniforge3/envs/tf-metal/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### GridSearchCV

# %%
from sklearn.metrics import  make_scorer
cv_params = {'max_depth': [6,7],'n_estimators':[500,800],
             'learing_rate' : [0.1,0.2]}    # parameters to be tries in the grid search
fix_params = { 'objective':'multi:softprob'}   #other parameters, fixed for the moment 

scorer = make_scorer(recall_score, average='weighted')
csv = GridSearchCV(xgb.XGBClassifier(**fix_params), cv_params,
                   scoring = scorer, cv = 3)

# %%
csv.fit(X_train, y_train)
# Out:
# [20:43:43] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:44:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:44:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:45:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:46:07] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:46:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:47:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:48:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:48:41] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:49:14] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:49:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:50:43] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:51:27] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:52:01] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:52:35] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:53:08] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:53:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:54:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:55:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:55:56] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [20:56:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:57:04] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:57:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:58:34] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:59:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None,
#                                      objective='multi:softprob', predictor=None,
#                                      random_state=None, reg_alpha=None, ...),
#              param_grid={'learing_rate': [0.1, 0.2], 'max_depth': [6, 7],
#                          'n_estimators': [500, 800]},
#              scoring=make_scorer(recall_score, average=weighted))

# %%
csv.best_params_
# Out:
# {'learing_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}

# %%
csv.cv_results_
# Out:
# {'mean_fit_time': array([32.91639249, 43.95515466, 33.18121338, 44.45966164, 33.57648563,
#         44.77849245, 33.64752738, 44.914277  ]),
#  'std_fit_time': array([0.36451388, 0.35760576, 0.31702859, 0.41158145, 0.38184467,
#         0.4360071 , 0.29800465, 0.50925624]),
#  'mean_score_time': array([0.03713536, 0.03797992, 0.03669937, 0.03676136, 0.03646477,
#         0.03701488, 0.03685872, 0.03771138]),
#  'std_score_time': array([6.35341123e-04, 3.16614268e-04, 3.31126319e-05, 3.54452999e-04,
#         7.08410952e-04, 4.38162511e-04, 1.27932981e-03, 3.13199687e-04]),
#  'param_learing_rate': masked_array(data=[0.1, 0.1, 0.1, 0.1, 0.2, 0.2, 0.2, 0.2],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[6, 6, 7, 7, 6, 6, 7, 7],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[500, 800, 500, 800, 500, 800, 500, 800],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'learing_rate': 0.1, 'max_depth': 6, 'n_estimators': 500},
#   {'learing_rate': 0.1, 'max_depth': 6, 'n_estimators': 800},
#   {'learing_rate': 0.1, 'max_depth': 7, 'n_estimators': 500},
#   {'learing_rate': 0.1, 'max_depth': 7, 'n_estimators': 800},
#   {'learing_rate': 0.2, 'max_depth': 6, 'n_estimators': 500},
#   {'learing_rate': 0.2, 'max_depth': 6, 'n_estimators': 800},
#   {'learing_rate': 0.2, 'max_depth': 7, 'n_estimators': 500},
#   {'learing_rate': 0.2, 'max_depth': 7, 'n_estimators': 800}],
#  'split0_test_score': array([0.73333333, 0.72820513, 0.75128205, 0.74358974, 0.73333333,
#         0.72820513, 0.75128205, 0.74358974]),
#  'split1_test_score': array([0.72307692, 0.71538462, 0.73589744, 0.73333333, 0.72307692,
#         0.71538462, 0.73589744, 0.73333333]),
#  'split2_test_score': array([0.75835476, 0.75578406, 0.72236504, 0.70694087, 0.75835476,
#         0.75578406, 0.72236504, 0.70694087]),
#  'mean_test_score': array([0.738255  , 0.7331246 , 0.73651484, 0.72795465, 0.738255  ,
#         0.7331246 , 0.73651484, 0.72795465]),
#  'std_test_score': array([0.01481662, 0.01685585, 0.01181339, 0.01543767, 0.01481662,
#         0.01685585, 0.01181339, 0.01543767]),
#  'rank_test_score': array([1, 5, 3, 7, 1, 5, 3, 7], dtype=int32)}

# %%
model_gs = xgb.XGBClassifier( learing_rate =  0.1,  max_depth= 6, n_estiamtors = 500,
                             min_child_weight=  1, eval_metric = 'merror', objective='multi:softprob' ) 

# Fit the model
model_gs.fit(X_train_, y_train_)

predictions_gs = model_gs.predict(X_valid_)
accuracy_gs = accuracy_score(y_valid_, predictions_gs)
print("Accuracy: %.2f%%" % (accuracy_gs * 100.0))

recall_gs = recall_score(y_valid_, predictions_gs, average= 'weighted')
print("recall: %.2f%%" % (recall_gs * 100.0))

precision_gs = precision_score(y_valid_, predictions_gs, average= 'weighted')
print("precision: %.2f%%" % (precision_gs * 100.0))

plot_confusion_matrix(model_gs, X_valid_, y_valid_)  
plt.show()
# Out:
# [21:00:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1662013895516/work/src/learner.cc:627:
# Parameters: { "learing_rate", "n_estiamtors" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# Accuracy: 88.74%
# recall: 88.74%
# precision: 89.03%
# /Users/ecem/miniforge3/envs/tf-metal/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
rocauc_gs = ROCAUC(model_gs, size=(1000, 700), classes=classes)

rocauc_gs.fit(X_train_, y_train_)       
rocauc_gs.score(X_valid_, y_valid_)  
r_gs = rocauc_.poof()

report_gs = ClassificationReport(model_gs, size=(1080, 720), classes=classes)

report_gs.score(X_valid_, y_valid_)
c_gs = report_gs.poof()
# Out:
# /Users/ecem/miniforge3/envs/tf-metal/lib/python3.9/site-packages/yellowbrick/classifier/base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   warnings.warn(
