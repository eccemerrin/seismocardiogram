# %%
import pandas as pd 
from scipy.stats import mannwhitneyu
from scipy import stats
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
csv_path = "/Users/ecem/Desktop/csv of scgs"

# %% [markdown]
# # SPECTOGRAM

# %%
spec = pd.read_csv(csv_path + "/multiple-disease-spectogram_coef.csv", index_col = 0)

# %%
array = spec.drop(['disease1', 'disease2'], axis =1).to_numpy()
array.shape
# Out:
# (327, 6144)

# %%
merged_list = [5317, 5321, 5324, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672,
       1673, 1674, 1675, 1676, 1677, 1678, 1679, 5368, 5372, 5780, 5781,
       5379, 5380, 5818, 5819, 5214, 5215, 5216, 5238, 5239, 5240, 5241,
       5242, 5243, 5244, 5245, 5246, 5247, 5248, 5249, 5250, 5251, 5252,
       5253, 5254, 5255, 5256, 5257, 5258, 5259, 5260, 5261, 5262, 5263,
       5264, 5265, 5266, 5267, 5268, 5269, 5270, 5271, 5272, 5273, 5274,
       5275, 5276, 5277, 5278, 5279, 5280, 5281, 5282, 5283, 5284, 5285,
       5286, 5287, 5288, 5289, 5290, 5291, 5292, 5296, 5297, 5298, 5299,
       5300, 5301, 5302, 5303, 5304, 5305, 5306, 5307, 5308, 5309, 5310,
       5311, 5312, 5313, 5314, 5315, 5316, 1221, 1222, 1223, 1224, 5318,
       5319, 5320, 5322, 5325, 1230, 5326, 5327, 5328, 5329, 5323, 1229,
       1231, 5334, 1232, 1233, 1234, 5330, 5331, 5332, 5333, 5335, 5336,
       5354, 5355, 5356, 5357, 5358, 5359, 5360, 5361, 5362, 5363, 5364,
       5365, 5366, 1269, 1270, 1271, 5367, 5369, 1274, 1275, 5370, 5371,
       5376, 5377, 5378, 1276, 1277, 5373, 5374, 5375, 5381, 5382, 5383,
       5384, 5385, 5386, 5387, 5390, 5391, 5388, 5389, 5392, 5393, 5394,
       5395, 5396, 5397, 5398, 5399, 5400, 5401, 5402, 5406, 5407, 5403,
       5404, 5405, 5408, 5409, 5413, 5414, 5410, 5411, 5412, 5415, 5416,
       5417, 5418, 5419, 5420, 5421, 5422, 5423, 5424, 5425, 5426, 5427,
       5428, 5429, 5430, 5434, 5431, 5432, 5433, 5435, 5439, 5436, 5437,
       5438, 5440, 5441, 5442, 5443, 5445, 5446, 5447, 5448, 5449, 5444,
       5454, 5455, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370,
       1371, 1372, 1416, 1417, 1418, 1463, 1464, 1465, 1466, 1467, 1468,
       1469, 1470, 1471, 1472, 1473, 1474, 1483, 1501, 1502, 1503, 1504,
       1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515,
       1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1548, 1549,
       1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560,
       1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1580,
       1581, 1582, 1583, 1584, 1585, 1605, 1606, 1607, 1608, 1609, 1610,
       1611, 1612, 5721, 5722, 5723, 5724, 5725, 5726, 5727, 5728, 5729,
       5730, 5731, 5732, 5733, 5734, 5735, 5736, 1653, 1654, 1655, 1656,
       1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 3713, 3714, 3715,
       3716, 3717, 3718, 3719, 3720, 3721, 3722, 3723, 3724, 3725, 3726,
       3727, 3728, 3729, 3730, 3731, 3732, 3733, 3734, 3735, 3736, 3737,
       3738, 3739, 3740, 3741, 3742, 5782, 5783, 1688, 1689, 1690, 1691,
       1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702,
       1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713,
       1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1740,
       1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751,
       1752, 1753, 1754, 1755, 1756, 1757, 5854, 1759, 1758, 5852, 5853,
       5856, 5857, 1765, 1766, 5855, 1760, 1761, 1762, 1763, 1764, 1767,
       1768, 1769, 1770, 3830, 3831, 3832, 3833, 1783, 1784, 5884, 5885,
       5886, 5887, 5888, 5889, 5890, 1819, 1820, 1821, 1822, 1823, 1824,
       1825, 1826, 1827, 1828, 1829, 3931, 3932, 3950, 3951, 3952, 3953,
       3954, 3955, 4002, 4003, 4004, 4005, 4006, 4007, 4008, 4009, 4010,
       4011, 4012, 6060, 6068, 6069, 6070, 6071, 6072, 6073, 6074, 6075,
       6076, 4025, 4026, 4027, 4028, 6081, 4029, 4030, 4031, 1993, 2000,
       2001, 6101, 6102, 6103, 6104, 6105, 6106, 6107, 6108, 1217, 1218,
       1219, 1220]

# %%
merged_list =np.array(merged_list)

# %%
filtered_spec = spec.iloc[:,merged_list]
#filtered_spec

# %%
filtered_spec.to_csv(csv_path + '/p-value-selected-intersection-multiple-dis-spec.csv')

# %% [markdown]
# # Sıgnal processing

# %%
def shortcut_sp(array1, array2, l = 1):
    p_value = []
    df_list = []
    
    if l == 1:
        test = mannwhitneyu(array1, array2, use_continuity = False, alternative = 'two-sided', axis = 0)
        stats = pd.DataFrame(test[0])
        p_value = pd.DataFrame(test[1]).T
        
        display(p_value.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x],
                                              axis = 1))
    else:
        for i in range(l):
            test = mannwhitneyu(array1, array2, use_continuity = False, alternative = 'two-sided', axis = 1)
            stats = pd.DataFrame(test[0])
            p_value.append(pd.DataFrame(test[1]))

            df_list.append(p_value[i].style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x],
                                                  axis = 1))
            display(df_list[i])

# %% [markdown]
# # *Zero Crossing Rate

# %%
signal_proc = pd.read_csv(csv_path + "/multiple-disease-final-signal_processing.csv", index_col = 0)
zcr = signal_proc.iloc[:,0:21]
zcr
zcr_ = zcr.to_numpy()
zcr_.shape
# Out:
# (327, 21)

# %%
#signal_proc
# Out:
#        zcr_x0    zcr_y0    zcr_z0    zcr_x1    zcr_y1    zcr_z1    zcr_x2  \
# 0    0.104004  0.149414  0.196777  0.188477  0.141602  0.096191  0.051270
# 1    0.093750  0.144531  0.183594  0.173828  0.137695  0.086914  0.047852
# 2    0.098145  0.149414  0.204590  0.214355  0.154785  0.104004  0.065918
# 3    0.112305  0.170410  0.221191  0.195312  0.147949  0.089844  0.064941
# 4    0.086426  0.127441  0.167480  0.167480  0.117188  0.075684  0.052246
# ..        ...       ...       ...       ...       ...       ...       ...
# 322  0.065430  0.095703  0.118164  0.112305  0.080078  0.049316  0.002930
# 323  0.061523  0.107910  0.138184  0.145996  0.108887  0.062500  0.025391
# 324  0.081055  0.121582  0.143555  0.128906  0.089355  0.048828  0.000000
# 325  0.033203  0.044434  0.064453  0.072266  0.048340  0.037109  0.000000
# 326  0.031250  0.073730  0.096191  0.077148  0.065918  0.023438  0.000977
#
#        zcr_y2    zcr_z2    zcr_x3  ...  tempogram_y381  tempogram_z381  \
# ...

# %% [markdown]
# ### ms-as vs ms-mr

# %%
shortcut_sp(zcr_[:82], zcr_[82:120])
# Out:
# <style type="text/css">
# #T_96b2c_row0_col0, #T_96b2c_row0_col1, #T_96b2c_row0_col2, #T_96b2c_row0_col3, #T_96b2c_row0_col4, #T_96b2c_row0_col5, #T_96b2c_row0_col6, #T_96b2c_row0_col7, #T_96b2c_row0_col8, #T_96b2c_row0_col9, #T_96b2c_row0_col10, #T_96b2c_row0_col11, #T_96b2c_row0_col18, #T_96b2c_row0_col19 {
#   background: pink;
# }
# </style>
# <table id="T_96b2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96b2c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_96b2c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_96b2c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_96b2c_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_96b2c_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_96b2c_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_96b2c_level0_col6" class="col_heading level0 col6" >6</th>
# ...

# %% [markdown]
# ### ms-as vs mr-as

# %%
shortcut_sp(zcr_[:82], zcr_[120:202])
# Out:
# <style type="text/css">
# #T_fa5f3_row0_col0, #T_fa5f3_row0_col1, #T_fa5f3_row0_col2, #T_fa5f3_row0_col3, #T_fa5f3_row0_col4, #T_fa5f3_row0_col5, #T_fa5f3_row0_col12, #T_fa5f3_row0_col13, #T_fa5f3_row0_col14, #T_fa5f3_row0_col15, #T_fa5f3_row0_col16, #T_fa5f3_row0_col17, #T_fa5f3_row0_col18, #T_fa5f3_row0_col20 {
#   background: pink;
# }
# </style>
# <table id="T_fa5f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa5f3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_fa5f3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_fa5f3_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_fa5f3_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_fa5f3_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_fa5f3_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_fa5f3_level0_col6" class="col_heading level0 col6" >6</th>
# ...

# %% [markdown]
# ### ms-as vs mr-ar

# %%
shortcut_sp(zcr_[:82], zcr_[202:284])
# Out:
# <style type="text/css">
# </style>
# <table id="T_b889d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b889d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b889d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b889d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b889d_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_b889d_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_b889d_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_b889d_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_b889d_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_b889d_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_b889d_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_b889d_level0_col10" class="col_heading level0 col10" >10</th>
# ...

# %% [markdown]
# ### ms-as vs ar-as

# %%
shortcut_sp(zcr_[:82], zcr_[284:])
# Out:
# <style type="text/css">
# #T_28f7a_row0_col12, #T_28f7a_row0_col13, #T_28f7a_row0_col14, #T_28f7a_row0_col15, #T_28f7a_row0_col16, #T_28f7a_row0_col17, #T_28f7a_row0_col20 {
#   background: pink;
# }
# </style>
# <table id="T_28f7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28f7a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_28f7a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_28f7a_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_28f7a_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_28f7a_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_28f7a_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_28f7a_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_28f7a_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_28f7a_level0_col8" class="col_heading level0 col8" >8</th>
# ...

# %% [markdown]
# ### ms-mr vs mr-as

# %%
shortcut_sp(zcr_[82:120], zcr_[120:202])
# Out:
# <style type="text/css">
# #T_6a22a_row0_col0, #T_6a22a_row0_col1, #T_6a22a_row0_col2, #T_6a22a_row0_col3, #T_6a22a_row0_col4, #T_6a22a_row0_col5, #T_6a22a_row0_col6, #T_6a22a_row0_col7, #T_6a22a_row0_col8, #T_6a22a_row0_col9, #T_6a22a_row0_col10, #T_6a22a_row0_col11, #T_6a22a_row0_col12, #T_6a22a_row0_col13, #T_6a22a_row0_col14, #T_6a22a_row0_col15, #T_6a22a_row0_col16, #T_6a22a_row0_col17, #T_6a22a_row0_col18, #T_6a22a_row0_col19, #T_6a22a_row0_col20 {
#   background: pink;
# }
# </style>
# <table id="T_6a22a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a22a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6a22a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6a22a_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_6a22a_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_6a22a_level0_col4" class="col_heading level0 col4" >4</th>
# ...

# %% [markdown]
# ### ms-mr vs mr-ar

# %%
shortcut_sp(zcr_[82:120], zcr_[202:284])
# Out:
# <style type="text/css">
# #T_9af1f_row0_col0, #T_9af1f_row0_col1, #T_9af1f_row0_col2, #T_9af1f_row0_col3, #T_9af1f_row0_col4, #T_9af1f_row0_col5, #T_9af1f_row0_col8, #T_9af1f_row0_col9, #T_9af1f_row0_col10, #T_9af1f_row0_col11, #T_9af1f_row0_col12, #T_9af1f_row0_col13, #T_9af1f_row0_col14, #T_9af1f_row0_col15, #T_9af1f_row0_col16, #T_9af1f_row0_col17, #T_9af1f_row0_col18, #T_9af1f_row0_col19, #T_9af1f_row0_col20 {
#   background: pink;
# }
# </style>
# <table id="T_9af1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9af1f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9af1f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9af1f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_9af1f_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_9af1f_level0_col4" class="col_heading level0 col4" >4</th>
# ...

# %% [markdown]
# ### ms-mr vs ar-as

# %%
shortcut_sp(zcr_[82:120], zcr_[284:])
# Out:
# <style type="text/css">
# #T_e2b82_row0_col0, #T_e2b82_row0_col1, #T_e2b82_row0_col2, #T_e2b82_row0_col3, #T_e2b82_row0_col4, #T_e2b82_row0_col5, #T_e2b82_row0_col6, #T_e2b82_row0_col7, #T_e2b82_row0_col8, #T_e2b82_row0_col9, #T_e2b82_row0_col10, #T_e2b82_row0_col11, #T_e2b82_row0_col12, #T_e2b82_row0_col13, #T_e2b82_row0_col14, #T_e2b82_row0_col15, #T_e2b82_row0_col16, #T_e2b82_row0_col17, #T_e2b82_row0_col18, #T_e2b82_row0_col19, #T_e2b82_row0_col20 {
#   background: pink;
# }
# </style>
# <table id="T_e2b82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2b82_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e2b82_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e2b82_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e2b82_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_e2b82_level0_col4" class="col_heading level0 col4" >4</th>
# ...

# %% [markdown]
# ### mr-as vs mr-ar

# %%
shortcut_sp(zcr_[120:202], zcr_[202:284])
# Out:
# <style type="text/css">
# #T_2d879_row0_col0, #T_2d879_row0_col1, #T_2d879_row0_col2, #T_2d879_row0_col3, #T_2d879_row0_col4, #T_2d879_row0_col5, #T_2d879_row0_col12, #T_2d879_row0_col13, #T_2d879_row0_col14, #T_2d879_row0_col15, #T_2d879_row0_col16, #T_2d879_row0_col17, #T_2d879_row0_col18, #T_2d879_row0_col20 {
#   background: pink;
# }
# </style>
# <table id="T_2d879">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d879_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2d879_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_2d879_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2d879_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_2d879_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_2d879_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_2d879_level0_col6" class="col_heading level0 col6" >6</th>
# ...

# %% [markdown]
# ### mr-as vs ar-as

# %%
shortcut_sp(zcr_[120:202], zcr_[284:])
# Out:
# <style type="text/css">
# #T_670aa_row0_col0, #T_670aa_row0_col1, #T_670aa_row0_col2, #T_670aa_row0_col3, #T_670aa_row0_col4, #T_670aa_row0_col5, #T_670aa_row0_col18 {
#   background: pink;
# }
# </style>
# <table id="T_670aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_670aa_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_670aa_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_670aa_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_670aa_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_670aa_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_670aa_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_670aa_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_670aa_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_670aa_level0_col8" class="col_heading level0 col8" >8</th>
# ...

# %% [markdown]
# ### mr-ar vs ar-as

# %%
shortcut_sp( zcr_[202:284], zcr_[284:])
# Out:
# <style type="text/css">
# #T_30fd6_row0_col12, #T_30fd6_row0_col13, #T_30fd6_row0_col14, #T_30fd6_row0_col15, #T_30fd6_row0_col16, #T_30fd6_row0_col17, #T_30fd6_row0_col20 {
#   background: pink;
# }
# </style>
# <table id="T_30fd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30fd6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_30fd6_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_30fd6_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_30fd6_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_30fd6_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_30fd6_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_30fd6_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_30fd6_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_30fd6_level0_col8" class="col_heading level0 col8" >8</th>
# ...

# %% [markdown]
# # *Chromogram

# %%
merged_list_ch =[32,  1,  4,  5,  6,  7, 27]

# %%
chro = signal_proc.iloc[:,21:57]
#chro

# %%
chro = chro.iloc[:,np.array(merged_list_ch)]
chro
# Out:
#          A♯_z       C_y      C♯_y      C♯_z       D_x       D_y       A_x
# 0    0.898151  0.465531  0.514051  0.547413  0.656185  0.739712  0.655725
# 1    0.924117  0.473939  0.708674  0.700867  0.769493  0.803762  0.738146
# 2    0.923531  0.392634  0.630330  0.691809  0.833126  0.845480  0.728774
# 3    0.979937  0.410735  0.538759  0.552843  0.649974  0.709571  0.633180
# 4    0.921828  0.488668  0.683789  0.608681  0.740227  0.805843  0.678758
# ..        ...       ...       ...       ...       ...       ...       ...
# 322  0.923160  0.492128  0.563289  0.620287  0.512644  0.655851  0.522895
# 323  0.794955  0.486064  0.666815  0.681477  0.685774  0.721715  0.709370
# 324  0.978834  0.546043  0.702636  0.783930  0.685779  0.806930  0.751198
# 325  0.947354  0.490822  0.596342  0.618947  0.578295  0.707697  0.723225
# 326  0.723286  0.756829  0.713897  0.741284  0.852103  0.827145  0.545483
#
# [327 rows x 7 columns]

# %%
chro.to_csv(csv_path + "/p-value-selected-multiple-dis-chromogram.csv")

# %% [markdown]
# # *Tempogram

# %%
merged_list_t = [768, 769, 962, 961, 960, 959, 955, 956, 957, 958, 767]

# %%
temp = signal_proc.iloc[:,57:]
#temp

# %%
temp = temp.iloc[:,np.array(merged_list_t)]
temp
# Out:
#      tempogram_x256  tempogram_y256  tempogram_z320  tempogram_y320  \
# 0          0.476022        0.445113    1.978267e-09    2.062070e-08
# 1          0.553634        0.538619    2.086170e-09    2.166218e-08
# 2          0.631292        0.608095    2.098638e-09    2.191610e-08
# 3          0.721456        0.715791    2.025586e-09    2.105369e-08
# 4          0.767489        0.767121    1.932686e-09    2.006646e-08
# ..              ...             ...             ...             ...
# 322        0.383970        0.364195    2.059336e-09    2.124141e-08
# 323        0.424022        0.277581    1.249031e-09    1.333401e-08
# 324        0.493365        0.407483    1.720723e-09    1.811135e-08
# 325        0.303590        0.270778    1.720426e-09    1.781081e-08
# 326        0.551715        0.265343    1.493748e-10    1.867445e-09
#
#      tempogram_x320  tempogram_z319  tempogram_y318  tempogram_z318  \
# 0      9.183201e-08    2.766100e-07        0.000004    2.549855e-06
# ...

# %%
temp.to_csv(csv_path +  '/p-value-selected-multiple-dis-temp.csv')
