# %% [markdown]
# ## Imports:

# %%
import scipy.io
import os
import pandas
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plt_lab
import matplotlib.gridspec as gridspec
import obspy
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %% [markdown]
# ## Load data:
# We are going to use this data to plot spectograms of SCG signals.

# %%
healty_path = "/Users/ecem/Documents/GitHub/seismocardiogram/data/healty-dataset"
diseased_path = "/Users/ecem/Documents/GitHub/seismocardiogram/data/diseased-dataset/Raw_Recordings"

# %%
ar_ = np.load(diseased_path + "/trimmed_5_ar.npy", allow_pickle= True)

# %%
ar_.shape
# Out:
# (3, 242, 2560)

# %%
healty_ = np.load(healty_path + "/trimmed_5_healty.npy", allow_pickle = True)

# %%
def converter(array):
    x,y,z = [],[],[]
    for i in range(array.shape[1]):
        x.append(obspy.core.trace.Trace(array[0][i]))
        y.append(obspy.core.trace.Trace(array[1][i]))
        z.append(obspy.core.trace.Trace(array[2][i]))
        
        x[i].stats.sampling_rate = 256
        y[i].stats.sampling_rate = 256
        z[i].stats.sampling_rate = 256
    return [x,y,z]

# %%
ar_ = converter(ar_)
healty_ = converter(healty_)

# %%
#sanity check
for i in range(len(ar_[1])):
    print(ar_[0][0] == ar_[2][i])
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
from obspy.imaging.cm import obspy_sequential
import math
from matplotlib import mlab
from matplotlib.colors import Normalize

# %%
def _nearest_pow_2(x):
    a = math.pow(2, math.ceil(np.log2(x)))
    b = math.pow(2, math.floor(np.log2(x)))
    if abs(a - x) < abs(b - x):
        return a
    else:
        return b

# %%
def output_spectrogram(data, samp_rate, per_lap=0.9, wlen=None, log=False,
                outfile=None, fmt=None, axes=None, dbscale=False,
                mult=8.0, cmap=obspy_sequential, zorder=None, title=None,
                show=True, clip=[0.0, 1.0]):
 
    import matplotlib.pyplot as plt
    
    # enforce float for samp_rate
    samp_rate = float(samp_rate)

    # set wlen from samp_rate if not specified otherwise
    if not wlen:
        wlen = samp_rate / 100.

    npts = len(data)
    # nfft needs to be an integer, otherwise a deprecation will be raised
    # XXX add condition for too many windows => calculation takes for ever
    nfft = int(_nearest_pow_2(wlen * samp_rate))
    if nfft > npts:
        nfft = int(_nearest_pow_2(npts / 8.0))

    if mult is not None:
        mult = int(_nearest_pow_2(mult))
        mult = mult * nfft
    nlap = int(nfft * float(per_lap))

    data = data - np.array(data).mean()
    end = npts / samp_rate

    # Here we call not plt.specgram as this already produces a plot
    # matplotlib.mlab.specgram should be faster as it computes only the
    # arrays
    # XXX mlab.specgram uses fft, would be better and faster use rfft
    specgram, freq, time = mlab.specgram(data, Fs=samp_rate, NFFT=nfft,
                                         pad_to=mult, noverlap=nlap, mode = 'psd')

    # db scale and remove zero/offset for amplitude
    if dbscale:
        specgram = 10 * np.log10(specgram[1:, :])
    else:
        specgram = np.sqrt(specgram[1:, :])
    freq = freq[1:]
    
    vmin, vmax = clip
    if vmin < 0 or vmax > 1 or vmin >= vmax:
        msg = "Invalid parameters for clip option."
        raise ValueError(msg)
    _range = float(specgram.max() - specgram.min())
    vmin = specgram.min() + vmin * _range
    vmax = specgram.min() + vmax * _range
    norm = Normalize(vmin, vmax, clip=True)

    # calculate half bin width
    halfbin_time = (time[1] - time[0]) / 2.0
    halfbin_freq = (freq[1] - freq[0]) / 2.0

    # argument None is not allowed for kwargs on matplotlib python 3.3
    kwargs = {k: v for k, v in (('cmap', cmap), ('zorder', zorder))
              if v is not None}

    if log:
        # pcolor expects one bin more at the right end
        freq = np.concatenate((freq, [freq[-1] + 2 * halfbin_freq]))
        time = np.concatenate((time, [time[-1] + 2 * halfbin_time]))
        # center bin
        time -= halfbin_time
        freq -= halfbin_freq
        # Log scaling for frequency values (y-axis)
        ax.set_yscale('log')
        # Plot times
        ax.pcolormesh(time, freq, specgram, norm=norm, **kwargs)
    else:
        # this method is much much faster!
        specgram = np.flipud(specgram)
        # center bin
        extent = (time[0] - halfbin_time, time[-1] + halfbin_time,
                  freq[0] - halfbin_freq, freq[-1] + halfbin_freq)
    return [specgram, extent, end]

# %%
def freq_average(array):
    means= []
    for i in range(array.shape[0]):
        means.append(array[i][0:40].mean())
    return np.array(means)

# %%
def spec_values(array):
    x_, y_, z_ = [],[],[]
    for i in range(len(array[0])):
        _x = output_spectrogram(array[0][i].data, 256)[0]
        _y = output_spectrogram(array[1][i].data, 256)[0]
        _z = output_spectrogram(array[2][i].data, 256)[0]

        x_.append(freq_average(array = _x))
        y_.append(freq_average(array = _y))
        z_.append(freq_average(array = _z)) 
        
        
    return np.stack((x_, y_, z_), axis = 0)

# %%
healty = spec_values(healty_)
ar = spec_values(ar_)

# %%
print(ar.shape)
print(healty.shape)
# Out:
# (3, 242, 2048)
# (3, 282, 2048)

# %%
ar[0].shape
# Out:
# (242, 2048)

# %%
ar[0][70]
# Out:
# array([0.00050484, 0.00072888, 0.00075477, ..., 0.24832418, 0.25529167,
#        0.2589406 ])

# %% [markdown]
# # apply mann whitney u test

# %%
from scipy.stats import mannwhitneyu

# %%
from scipy import stats

# %% [markdown]
# ###  x components

# %%
test = mannwhitneyu(healty[0], ar[0], use_continuity=False, alternative = 'two-sided')
df_stats_x = pd.DataFrame(test[0])
df_p_x = pd.DataFrame(test[1])
df_p_x
# Out:
#                  0
# 0     8.420566e-87
# 1     8.420566e-87
# 2     8.420566e-87
# 3     8.420566e-87
# 4     8.420566e-87
# ...            ...
# 2043  8.615750e-87
# 2044  8.615750e-87
# 2045  8.615750e-87
# 2046  8.615750e-87
# 2047  8.615750e-87
#
# [2048 rows x 1 columns]

# %%
df_p_x.style.apply(lambda x: ["background: yellow" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_112e7_row0_col0, #T_112e7_row1_col0, #T_112e7_row2_col0, #T_112e7_row3_col0, #T_112e7_row4_col0, #T_112e7_row5_col0, #T_112e7_row6_col0, #T_112e7_row7_col0, #T_112e7_row8_col0, #T_112e7_row9_col0, #T_112e7_row10_col0, #T_112e7_row11_col0, #T_112e7_row12_col0, #T_112e7_row13_col0, #T_112e7_row14_col0, #T_112e7_row15_col0, #T_112e7_row16_col0, #T_112e7_row17_col0, #T_112e7_row18_col0, #T_112e7_row19_col0, #T_112e7_row20_col0, #T_112e7_row21_col0, #T_112e7_row22_col0, #T_112e7_row23_col0, #T_112e7_row24_col0, #T_112e7_row25_col0, #T_112e7_row26_col0, #T_112e7_row27_col0, #T_112e7_row28_col0, #T_112e7_row29_col0, #T_112e7_row30_col0, #T_112e7_row31_col0, #T_112e7_row32_col0, #T_112
_col0, #T_112e7_row156_col0, #T_112e7_row157_col0, #T_112e7_row158_col0, #T_112e7_row159_col0, #T_112e7_row160_col0, #T_112e7_row161_col0, #T_112e7_row162_col0, #T_112e7_row163_col0, #T_112e7_row164_col0, #T_112e7_row165_col0, #T_112e7_row166_col0, #T_112e7_row167_col0, #T_112e7_row168_col0, #T_112e7_row169_col0, #T_112e7_row170_col0, #T_112e7_row171_col0, #T_112e7_row172_col0, #T_112e7_row173_col0, #T_112e7_row174_col0, #T_112e7_row175_col0, #T_112e7_row176_col0, #T_112e7_row177_col0, #T_112e7_row178_col0, #T_112e7_row179_col0, #T_112e7_row180_col0, #T_112e7_row181_col0, #T_112e7_row182_col0, #T_112e7_row183_col0, #T_112e7_row184_col0, #T_112e7_row185_col0, #T_112e7_row186_co ...

# %% [markdown]
# ### -------- with two sample t test

# %%
p_val = pd.DataFrame(stats.ttest_ind(healty[0], ar[0])[1])
p_val.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_8148d_row0_col0, #T_8148d_row1_col0, #T_8148d_row2_col0, #T_8148d_row3_col0, #T_8148d_row4_col0, #T_8148d_row5_col0, #T_8148d_row6_col0, #T_8148d_row7_col0, #T_8148d_row8_col0, #T_8148d_row9_col0, #T_8148d_row10_col0, #T_8148d_row11_col0, #T_8148d_row12_col0, #T_8148d_row13_col0, #T_8148d_row14_col0, #T_8148d_row15_col0, #T_8148d_row16_col0, #T_8148d_row17_col0, #T_8148d_row18_col0, #T_8148d_row19_col0, #T_8148d_row20_col0, #T_8148d_row21_col0, #T_8148d_row22_col0, #T_8148d_row23_col0, #T_8148d_row24_col0, #T_8148d_row25_col0, #T_8148d_row26_col0, #T_8148d_row27_col0, #T_8148d_row28_col0, #T_8148d_row29_col0, #T_8148d_row30_col0, #T_8148d_row31_col0, #T_8148d_row32_col0, #T_8148d_row33_col0, #T_8148d_row34_col0, #T_8148d_row35_col0, #T_8148d_row36_col0, #T_8148d_row37_col0, #T_8148d_row38_col0, #T_8148d_row39_col0, #T_8148d_row40_col0, #T_8148d_row41_col0, #T_8148d_row42_col0, #T_8148d_row43_col0, #T_8148d_row44_col0, #T_8148d_row45_col0, #T_8148d_row46_col0, #T_8148d_row47_col0, #T_8148d_row48_col0, #T_8148d_row49_col0, #T_8148d_row50_col0, #T_8148d_row51_col0, #T_8148d_row52_col0, #T_8148d_row53_col0, #T_8148d_row54_col0, #T_8148d_row55_col0, #T_8148d_row56_col0, #T_8148d_row57_col0, #T_8148d_row58_col0, #T_8148d_row59_col0, #T_8148d_row60_col0, #T_8148d_row61_col0, #T_8148d_row62_col0, #T_8148d_row63_col0, #T_8148d_row64_col0, #T_8148d_row65_col0, #T_8148d_row66_col0, #T_8148d_row67_col0, #T_8148d_row68_col0, #T_8148d_row69_col0, #T_8148d_row70_col0, #T_8148d_row71_col0, #T_8148d_row72_col0, #T_8148d_row73_col0, #T_8148d_row74_col0, #T_8148d_row75_col0, #T_8148d_row76_col0, #T_8148d_row77_col0, #T_8148d_row78_col0, #T_8148d_row79_col0, #T_8148d_row80_col0, #T_8148d_row81_col0, #T_8148d_row82_col0, #T_8148d_row83_col0, #T_8148d_row84_col0, #T_8148d_row85_col0, #T_8148d_row86_col0, #T_8148d_row87_col0, #T_8148d_row88_col0, #T_8148d_row89_col0, #T_8148d_row90_col0, #T_8148d_row91_col0, #T_8148d_row92_col0, #T_8148d_row93_col0, #T_8148d_row94_col0, #T_8148d_row95_col0, #T_8148d_row96_col0, #T_8148d_row97_col0, #T_8148d_row98_col0, #T_8148d_row99_col0, #T_8148d_row100_col0, #T_8148d_row101_col0, #T_8148d_row102_col0, #T_8148d_row103_col0, #T_8148d_row104_col0, #T_8148d_row105_col0, #T_8148d_row106_col0, #T_8148d_row107_col0, #T_8148d_row108_col0, #T_8148d_row109_col0, #T_8148d_row110_col0, #T_8148d_row111_col0, #T_8148d_row112_col0, #T_8148d_row113_col0, #T_8148d_row114_col0, #T_8148d_row115_col0, #T_8148d_row116_col0, #T_8148d_row117_col0, #T_8148d_row118_col0, #T_8148d_row119_col0, #T_8148d_row120_col0, #T_8148d_row121_col0, #T_8148d_row122_col0, #T_8148d_row123_col0, #T_8148d_row124_col0, #T_8148d_row125_col0, #T_8148d_row126_col0, #T_8148d_row127_col0, #T_8148d_row128_col0, #T_8148d_row129_col0, #T_8148d_row130_col0, #T_8148d_row131_col0, #T_8148d_row132_col0, #T_8148d_row133_col0, #T_8148d_row134_col0, #T_8148d_row135_col0, #T_8148d_row136_col0, #T_8148d_row137_col0, #T_8148d_row138_col0, #T_8148d_row139_col0, #T_8148d_row140_col0, #T_8148d_row141_col0, #T_8148d_row142_col0, #T_8148d_row143_col0, #T_8148d_row144_col0, #T_8148d_row145_col0, #T_8148d_row146_col0, #T_8148d_row147_col0, #T_8148d_row148_col0, #T_8148d_row149_col0, #T_8148d_row150_col0, #T_8148d_row151_col0, #T_8148d_row152_col0, #T_8148d_row153_col0, #T_8148d_row154_col0, #T_8148d_row155_col0, #T_8148d_row156_col0, #T_8148d_row157_col0, #T_8148d_row158_col0, #T_8148d_row159_col0, #T_8148d_row160_col0, #T_8148d_row161_col0, #T_8148d_row162_col0, #T_8148d_row163_col0, #T_8148d_row164_col0, #T_8148d_row165_col0, #T_8148d_row166_col0, #T_8148d_row167_col0, #T_8148d_row168_col0, #T_8148d_row169_col0, #T_8148d_row170_col0, #T_8148d_row171_col0, #T_8148d_row172_col0, #T_8148d_row173_col0, #T_8148d_row174_col0, #T_8148d_row175_col0, #T_8148d_row176_col0, #T_8148d_row177_col0, #T_8148d_row178_col0, #T_8148d_row179_col0, #T_8148d_row180_col0, #T_8148d_row181_col0, #T_8148d_row182_col0, #T_8148d_row183_col0, #T_8148d_row184_col0, #T_8148d_row185_col0, #T_8148d_row186_co ...

# %% [markdown]
# ### y component

# %%
test_y = mannwhitneyu(healty[1], ar[1], use_continuity=False, alternative = 'two-sided')
df_stats_y = pd.DataFrame(test_y[1])
df_p_y = pd.DataFrame(test_y[1])
df_p_y
# Out:
#                  0
# 0     8.420566e-87
# 1     8.420566e-87
# 2     8.420566e-87
# 3     8.420566e-87
# 4     8.420566e-87
# ...            ...
# 2043  7.298260e-86
# 2044  8.272661e-86
# 2045  1.062782e-85
# 2046  1.164100e-85
# 2047  1.246360e-85
#
# [2048 rows x 1 columns]

# %%
df_p_y.style.apply(lambda x: ["background: yellow" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T
_eed5b_row113_col0, #T_eed5b_row114_col0, #T_eed5b_row115_col0, #T_eed5b_row116_col0, #T_eed5b_row117_col0, #T_eed5b_row118_col0, #T_eed5b_row119_col0, #T_eed5b_row120_col0, #T_eed5b_row121_col0, #T_eed5b_row122_col0, #T_eed5b_row123_col0, #T_eed5b_row124_col0, #T_eed5b_row125_col0, #T_eed5b_row126_col0, #T_eed5b_row127_col0, #T_eed5b_row128_col0, #T_eed5b_row129_col0, #T_eed5b_row130_col0, #T_eed5b_row131_col0, #T_eed5b_row132_col0, #T_eed5b_row133_col0, #T_eed5b_row134_col0, #T_eed5b_row135_col0, #T_eed5b_row136_col0, #T_eed5b_row137_col0, #T_eed5b_row138_col0, #T_eed5b_row139_col0, #T_eed5b_row140_col0, #T_eed5b_row141_col0, #T_eed5b_row142_col0, #T_eed5b_row143_col0, #T_eed5b_row144_col0, #T_eed5b_row145_col0, #T_eed5b_row146_col0, #T_eed5b_row147_col0, #T_eed5b_row148_col0, #T_eed5b_row149_col0, #T_eed5b_row150_col0, #T_eed5b_row151_col0, #T_eed5b_row152_col0, #T_eed5b_row153_col0, #T_eed5b_row154_col0, #T_eed5b_row155_col0, #T_eed5b_row156_col0, #T_eed5b_row157_col0, #T_eed5b_row158_col0, #T_eed5b_row159_col0, #T_eed5b_row160_col0, #T_eed5b_row161_col0, #T_eed5b_row162_col0, #T_eed5b_row163_col0, #T_eed5b_row164_col0, #T_eed5b_row165_col0, #T_eed5b_row166_col0, #T_eed5b_row167_col0, #T_eed5b_row168_col0, #T_eed5b_row169_col0, #T_eed5b_row170_col0, #T_eed5b_row171_col0, #T_eed5b_row172_col0, #T_eed5b_row173_col0, #T_eed5b_row174_col0, #T_eed5b_row175_col0, #T_eed5b_row176_col0, #T_eed5b_row177_col0, #T_eed5b_row178_col0, #T_eed5b_row179_col0, #T_eed5b_row180_col0, #T_eed5b_row181_col0, #T_eed5b_row182_col0, #T_eed5b_row183_col0, #T_eed5b_row184_col0, #T_eed5b_row185_col0, #T_eed5b_row186_co ...

# %% [markdown]
# ### --------- with two sample t test

# %%
p_val_y = pd.DataFrame(stats.ttest_ind(healty[1], ar[1])[1])
p_val_y.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_59dc8_row0_col0, #T_59dc8_row1_col0, #T_59dc8_row2_col0, #T_59dc8_row3_col0, #T_59dc8_row4_col0, #T_59dc8_row5_col0, #T_59dc8_row6_col0, #T_59dc8_row7_col0, #T_59dc8_row8_col0, #T_59dc8_row9_col0, #T_59dc8_row10_col0, #T_59dc8_row11_col0, #T_59dc8_row12_col0, #T_59dc8_row13_col0, #T_59dc8_row14_col0, #T_59dc8_row15_col0, #T_59dc8_row16_col0, #T_59dc8_row17_col0, #T_59dc8_row18_col0, #T_59dc8_row19_col0, #T_59dc8_row20_col0, #T_59dc8_row21_col0, #T_59dc8_row22_col0, #T_59dc8_row23_col0, #T_59dc8_row24_col0, #T_59dc8_row25_col0, #T_59dc8_row26_col0, #T_59dc8_row27_col0, #T_59dc8_row28_col0, #T_59dc8_row29_col0, #T_59dc8_row30_col0, #T_59dc8_row31_col0, #T_59dc8_row32_col0, #T_59dc8_row33_col0, #T_59dc8_row
dc8_row148_col0, #T_59dc8_row149_col0, #T_59dc8_row150_col0, #T_59dc8_row151_col0, #T_59dc8_row152_col0, #T_59dc8_row153_col0, #T_59dc8_row154_col0, #T_59dc8_row155_col0, #T_59dc8_row156_col0, #T_59dc8_row157_col0, #T_59dc8_row158_col0, #T_59dc8_row159_col0, #T_59dc8_row160_col0, #T_59dc8_row161_col0, #T_59dc8_row162_col0, #T_59dc8_row163_col0, #T_59dc8_row164_col0, #T_59dc8_row165_col0, #T_59dc8_row166_col0, #T_59dc8_row167_col0, #T_59dc8_row168_col0, #T_59dc8_row169_col0, #T_59dc8_row170_col0, #T_59dc8_row171_col0, #T_59dc8_row172_col0, #T_59dc8_row173_col0, #T_59dc8_row174_col0, #T_59dc8_row175_col0, #T_59dc8_row176_col0, #T_59dc8_row177_col0, #T_59dc8_row178_col0, #T_59dc8_row179_col0, #T_59dc8_row180_col0, #T_59dc8_row181_col0, #T_59dc8_row182_col0, #T_59dc8_row183_col0, #T_59dc8_row184_col0, #T_59dc8_row185_col0, #T_59dc8_row186_co ...

# %% [markdown]
# ### z component

# %%
test_z = mannwhitneyu(healty[2], ar[2], use_continuity=False, alternative = 'two-sided')
df_stats_z = pd.DataFrame(test_z[1])
df_p_z = pd.DataFrame(test_z[1])
df_p_z
# Out:
#                  0
# 0     8.420566e-87
# 1     8.420566e-87
# 2     8.420566e-87
# 3     8.420566e-87
# 4     8.420566e-87
# ...            ...
# 2043  8.917018e-87
# 2044  8.917018e-87
# 2045  9.019758e-87
# 2046  9.019758e-87
# 2047  9.019758e-87
#
# [2048 rows x 1 columns]

# %%
df_p_z.style.apply(lambda x: ["background: yellow" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_6c8b5_row0_col0, #T_6c8b5_row1_col0, #T_6c8b5_row2_col0, #T_6c8b5_row3_col0, #T_6c8b5_row4_col0, #T_6c8b5_row5_col0, #T_6c8b5_row6_col0, #T_6c8b5_row7_col0, #T_6c8b5_row8_col0, #T_6c8b5_row9_col0, #T_6c8b5_row10_col0, #T_6c8b5_row11_col0, #T_6c8b5_row12_col0, #T_6c8b5_row13_col0, #T_6c8b5_row14_col0, #T_6c8b5_row15_col0, #T_6c8b5_row16_col0, #T_6c8b5_row17_col0, #T_6c8b5_row18_col0, #T_6c8b5_row19_col0, #T_6c8b5_row20_col0, #T_6c8b5_row21_col0, #T_6c8b5_row22_col0, #T_6c8b5_row23_col0, #T_6c8b5_row24_col0, #T_6c8b5_row25_col0, #T_6c8b5_row26_col0, #T_6c8b5_row27_col0, #T_6c8b5_row28_col0, #T_6c8b5_row29_col0, #T_6c8b5_row30_col0, #T_6c8b5_row31_col0, #T_6c8b5_row32_col0, #T_6c8b5_row33_col0, #T_6c8b5_row34_col0, #T_6c8b5_row35_col0, #T_6c8b5_row36_col0, #T_6c8b5_row37_col0, #T_6c8b5_row38_col0, #T_6c8b5_row39_col0, #T_6c8b5_row40_col0, #T_6c8b5_row41_col0, #T_6c8b5_row42_col0, #T_6c8b5_row43_col0, #T_6c8b5_row44_col0, #T_6c8b5_row45_col0, #T_6c8b5_row46_col0, #T_6c8b5_row47_col0, #T_6c8b5_row48_col0, #T_6c8b5_row49_col
, #T_6c8b5_row156_col0, #T_6c8b5_row157_col0, #T_6c8b5_row158_col0, #T_6c8b5_row159_col0, #T_6c8b5_row160_col0, #T_6c8b5_row161_col0, #T_6c8b5_row162_col0, #T_6c8b5_row163_col0, #T_6c8b5_row164_col0, #T_6c8b5_row165_col0, #T_6c8b5_row166_col0, #T_6c8b5_row167_col0, #T_6c8b5_row168_col0, #T_6c8b5_row169_col0, #T_6c8b5_row170_col0, #T_6c8b5_row171_col0, #T_6c8b5_row172_col0, #T_6c8b5_row173_col0, #T_6c8b5_row174_col0, #T_6c8b5_row175_col0, #T_6c8b5_row176_col0, #T_6c8b5_row177_col0, #T_6c8b5_row178_col0, #T_6c8b5_row179_col0, #T_6c8b5_row180_col0, #T_6c8b5_row181_col0, #T_6c8b5_row182_col0, #T_6c8b5_row183_col0, #T_6c8b5_row184_col0, #T_6c8b5_row185_col0, #T_6c8b5_row186_co ...

# %% [markdown]
# ### --------- with two sample t test

# %%
p_val_y = pd.DataFrame(stats.ttest_ind(healty[1], ar[1])[1])
p_val_y.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_59ab6_row0_col0, #T_59ab6_row1_col0, #T_59ab6_row2_col0, #T_59ab6_row3_col0, #T_59ab6_row4_col0, #T_59ab6_row5_col0, #T_59ab6_row6_col0, #T_59ab6_row7_col0, #T_59ab6_row8_col0, #T_59ab6_row9_col0, #T_59ab6_row10_col0, #T_59ab6_row11_col0, #T_59ab6_row12_col0, #T_59ab6_row13_col0, #T_59ab6_row14_col0, #T_59ab6_row15_col0, #T_59ab6_row16_col0, #T_59ab6_row17_col0, #T_59ab6_row18_col0, #T_59ab6_row19_col0, #T_59ab6_row20_col0, #T_59ab6_row21_col0, #T_59ab6_row22_col0, #T_59ab6_row23_col0, #T_59ab6_row24_col0, #T_59ab6_row25_col0, #T_59ab6_row26_col0, #T_59ab6_row27_col0, #T_59ab6_row28_col0, #T_59ab6_row29_col0, #T_59ab6_row30_col0, #T_59ab6_row31_col0, #T_59ab6_row32_col0, #T_59ab6_row33_col0, #T_59ab6_row34_col0, #T_59ab6_row35_col0, #T_59ab6_row36_col0, #T_59ab6_row37_col0, #T_59ab6_row38_col0, #T_59ab6_row39_col0, #T_59ab6_row40_col0, #T_59ab6_row41_col0, #T_59ab6_row42_col0, #T_59ab6_row43_col0, #T_59ab6_row44_col0, #T_59ab6_row45_col0, #T_59ab6_row46_col0, #T_59ab6_row47_col0, #T_59ab6_row48_col0, #T_59ab6_row49_col0, #T_59ab6_row50_col0, #T_59ab6_row51_col0, #T_59ab6_row52_col0, #T_59ab6_row53_col0, #T_59ab6_row54_col0, #T_59ab6_row55_col0, #T_59ab6_row56_col0, #T_59ab6_row57_col0, #T_59ab6_row58_col0, #T_59ab6_row59_col0, #T_59ab6_row60_col0, #T_59ab6_row61_col0, #T_59ab6_row62_col0, #T_59ab6_row63_col0, #T_59ab6_row64_col0, #T_59ab6_row65_col0, #T_59ab6_row66_col0, #T_59ab6_row67_col0, #T_59ab6_row68_col0, #T_59ab6_row69_col0, #T_59ab6_row70_col0, #T_59ab6_row71_col0, #T_59ab6_row72_col0, #T_59ab