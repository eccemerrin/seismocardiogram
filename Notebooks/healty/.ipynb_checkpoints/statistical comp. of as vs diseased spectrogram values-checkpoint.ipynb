# %% [markdown]
# ## Imports:

# %%
import scipy.io
import os
import pandas
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plt_lab
import matplotlib.gridspec as gridspec
import obspy
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %% [markdown]
# ## Load data:
# We are going to use this data to plot spectograms of SCG signals.

# %%
healty_path = "/Users/ecem/Documents/GitHub/seismocardiogram/data/healty-dataset"
diseased_path = "/Users/ecem/Documents/GitHub/seismocardiogram/data/diseased-dataset/Raw_Recordings"

# %%
as_ = np.load(diseased_path + "/trimmed_5_as.npy", allow_pickle= True)

# %%
as_.shape
# Out:
# (3, 139, 2560)

# %%
healty_ = np.load(healty_path + "/trimmed_5_healty.npy", allow_pickle = True)

# %%
def converter(array):
    x,y,z = [],[],[]
    for i in range(array.shape[1]):
        x.append(obspy.core.trace.Trace(array[0][i]))
        y.append(obspy.core.trace.Trace(array[1][i]))
        z.append(obspy.core.trace.Trace(array[2][i]))
        
        x[i].stats.sampling_rate = 256
        y[i].stats.sampling_rate = 256
        z[i].stats.sampling_rate = 256
    return [x,y,z]

# %%
as_ = converter(as_)
healty_ = converter(healty_)

# %%
#sanity check
for i in range(len(as_[1])):
    print(as_[0][0] == as_[2][i])
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
from obspy.imaging.cm import obspy_sequential
import math
from matplotlib import mlab
from matplotlib.colors import Normalize

# %%
def _nearest_pow_2(x):
    a = math.pow(2, math.ceil(np.log2(x)))
    b = math.pow(2, math.floor(np.log2(x)))
    if abs(a - x) < abs(b - x):
        return a
    else:
        return b

# %%
def output_spectrogram(data, samp_rate, per_lap=0.9, wlen=None, log=False,
                outfile=None, fmt=None, axes=None, dbscale=False,
                mult=8.0, cmap=obspy_sequential, zorder=None, title=None,
                show=True, clip=[0.0, 1.0]):
 
    import matplotlib.pyplot as plt
    
    # enforce float for samp_rate
    samp_rate = float(samp_rate)

    # set wlen from samp_rate if not specified otherwise
    if not wlen:
        wlen = samp_rate / 100.

    npts = len(data)
    # nfft needs to be an integer, otherwise a deprecation will be raised
    # XXX add condition for too many windows => calculation takes for ever
    nfft = int(_nearest_pow_2(wlen * samp_rate))
    if nfft > npts:
        nfft = int(_nearest_pow_2(npts / 8.0))

    if mult is not None:
        mult = int(_nearest_pow_2(mult))
        mult = mult * nfft
    nlap = int(nfft * float(per_lap))

    data = data - np.array(data).mean()
    end = npts / samp_rate

    # Here we call not plt.specgram as this already produces a plot
    # matplotlib.mlab.specgram should be faster as it computes only the
    # arrays
    # XXX mlab.specgram uses fft, would be better and faster use rfft
    specgram, freq, time = mlab.specgram(data, Fs=samp_rate, NFFT=nfft,
                                         pad_to=mult, noverlap=nlap, mode = 'psd')

    # db scale and remove zero/offset for amplitude
    if dbscale:
        specgram = 10 * np.log10(specgram[1:, :])
    else:
        specgram = np.sqrt(specgram[1:, :])
    freq = freq[1:]
    
    vmin, vmax = clip
    if vmin < 0 or vmax > 1 or vmin >= vmax:
        msg = "Invalid parameters for clip option."
        raise ValueError(msg)
    _range = float(specgram.max() - specgram.min())
    vmin = specgram.min() + vmin * _range
    vmax = specgram.min() + vmax * _range
    norm = Normalize(vmin, vmax, clip=True)

    # calculate half bin width
    halfbin_time = (time[1] - time[0]) / 2.0
    halfbin_freq = (freq[1] - freq[0]) / 2.0

    # argument None is not allowed for kwargs on matplotlib python 3.3
    kwargs = {k: v for k, v in (('cmap', cmap), ('zorder', zorder))
              if v is not None}

    if log:
        # pcolor expects one bin more at the right end
        freq = np.concatenate((freq, [freq[-1] + 2 * halfbin_freq]))
        time = np.concatenate((time, [time[-1] + 2 * halfbin_time]))
        # center bin
        time -= halfbin_time
        freq -= halfbin_freq
        # Log scaling for frequency values (y-axis)
        ax.set_yscale('log')
        # Plot times
        ax.pcolormesh(time, freq, specgram, norm=norm, **kwargs)
    else:
        # this method is much much faster!
        specgram = np.flipud(specgram)
        # center bin
        extent = (time[0] - halfbin_time, time[-1] + halfbin_time,
                  freq[0] - halfbin_freq, freq[-1] + halfbin_freq)
    return [specgram, extent, end]

# %%
def freq_average(array):
    means= []
    for i in range(array.shape[0]):
        means.append(array[i][0:40].mean())
    return np.array(means)

# %%
def spec_values(array):
    x_, y_, z_ = [],[],[]
    for i in range(len(array[0])):
        _x = output_spectrogram(array[0][i].data, 256)[0]
        _y = output_spectrogram(array[1][i].data, 256)[0]
        _z = output_spectrogram(array[2][i].data, 256)[0]

        x_.append(freq_average(array = _x))
        y_.append(freq_average(array = _y))
        z_.append(freq_average(array = _z)) 
        
        
    return np.stack((x_, y_, z_), axis = 0)

# %%
healty = spec_values(healty_)
ass = spec_values(as_)

# %%
print(ass.shape)
print(healty.shape)
# Out:
# (3, 139, 2048)
# (3, 282, 2048)

# %%
ass[0].shape
# Out:
# (139, 2048)

# %%
ass[0][70]
# Out:
# array([0.00057072, 0.00081651, 0.00082678, ..., 0.03975494, 0.04164825,
#        0.04280185])

# %% [markdown]
# # apply mann whitney u test

# %%
from scipy.stats import mannwhitneyu

# %%
from scipy import stats

# %% [markdown]
# ###  x components

# %%
test = mannwhitneyu(healty[0], ass[0], use_continuity=False, alternative = 'two-sided')
df_stats_x = pd.DataFrame(test[0])
df_p_x = pd.DataFrame(test[1])
df_p_x
# Out:
#                  0
# 0     1.471893e-62
# 1     1.471893e-62
# 2     1.471893e-62
# 3     1.471893e-62
# 4     1.471893e-62
# ...            ...
# 2043  1.471893e-62
# 2044  1.471893e-62
# 2045  1.471893e-62
# 2046  1.471893e-62
# 2047  1.471893e-62
#
# [2048 rows x 1 columns]

# %%
df_p_x.style.apply(lambda x: ["background: yellow" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_eb699_row0_col0, #T_eb699_row1_col0, #T_eb699_row2_col0, #T_eb699_row3_col0, #T_eb699_row4_col0, #T_eb699_row5_col0, #T_eb699_row6_col0, #T_eb699_row7_col0, #T_eb699_row8_col0, #T_eb699_row9_col0, #T_eb699_row10_col0, #T_eb699_row11_col0, #T_eb699_row12_col0, #T_eb699_row13_col0, #T_eb699_row14_col0, #T_eb699_row15_col0, #T_eb699_row16_col0, #T_eb699_row17_col0, #T_eb699_row18_col0, #T_eb699_row19_col0, #T_eb699_row20_col0, #T_eb699_row21_col0, #T_eb699_row22_col0, #T_eb699_row23_col0, #T_eb699_row24_col0, #T_eb699_row25_col0, #T_eb699_row26_col0, #T_eb699_row27_col0, #T_eb699_row28_col0, #T_eb699_row29_col0, #T_eb699_row30_col0, #T_eb699_row31_col0, #T_eb699_row32_col0, #T_eb699_row33_col0, #T_eb699_row34_col0, #T_eb699_row35_col0, #T_eb699_row36_col0, #T_eb699_row37_col0, #T_eb699_row38_col0, #T_eb699_row39_col0, #T_eb699_row40_col0, #T_eb699_row41_col0, #T_eb699_row42_col0, #T_eb699_row43_col0, #T_eb699_row44_col0, #T_eb699_row45_col0, #T_eb699_row46_col0, #T_eb699_row47_col0, #T_eb699_row48_col0, #T_eb699_row49_col0, #T_eb699_row50_col0, #T_eb699_row51_col0, #T_eb699_row52_col0, #T_eb699_row53_col0, #T_eb699_row54_col0, #T_eb699_row55_col0, #T_eb699_row56_col0, #T_eb699_row57_col0, #T_eb699_row58_col0, #T_eb699_row59_col0, #T_eb699_row60_col0, #T_eb699_row61_col0, #T_eb699_row62_col0, #T_eb699_row63_col0, #T_eb699_row64_col0, #T_eb699_row65_col0, #T_eb699_row66_col0, #T_eb699_row67_col0, #T_eb699_row68_col0, #T_eb699_row69_col0, #T_eb699_row70_col0, #T_eb699_row71_col0, #T_eb699_row72_col0, #T_eb699_row73_col0, #T_eb699_row74_col0, #T_eb699_row75_col0, #T_eb699_row76_col0, #T_eb699_row77_col0, #T_eb699_row78_col0, #T_eb699_row79_col0, #T_eb699_row80_col0, #T_eb699_row81_col0, #T_eb699_row82_col0, #T_eb699_row83_col0, #T_eb699_row84_col0, #T_eb699_row85_col0, #T_eb699_row86_col0, #T_eb699_row87_col0, #T_eb699_row88_col0, #T_eb699_row89_col0, #T_eb699_row90_col0, #T_eb699_row91_col0, #T_eb699_row92_col0, #T_eb699_row93_col0, #T_eb699_row94_col0, #T_eb699_row95_col0, #T_eb699_row96_col0, #T_eb699_row97_col0, #T_eb699_row98_col0, #T_eb699_row99_col0, #T_eb699_row100_col0, #T_eb699_row101_col0, #T_eb699_row102_col0, #T_eb699_row103_col0, #T_eb699_row104_col0, #T_eb699_row105_col0, #T_eb699_row106_col0, #T_eb699_row107_col0, #T_eb699_row108_col0, #T_eb699_row109_col0, #T_eb699_row110_col0, #T_eb699_row111_col0, #T_eb699_row112_col0, #T_eb699_row113_col0, #T_eb699_row114_col0, #T_eb699_row115_col0, #T_eb699_row116_col0, #T_eb699_row117_col0, #T_eb699_row118_col0, #T_eb699_row119_col0, #T_eb699_row120_col0, #T_eb699_row121_col0, #T_eb699_row122_col0, #T_eb699_row123_col0, #T_eb699_row124_col0, #T_eb699_row125_col0, #T_eb699_row126_col0, #T_eb699_row127_col0, #T_eb699_row128_col0, #T_eb699_row129_col0, #T_eb699_row130_col0, #T_eb699_row131_col0, #T_eb699_row132_col0, #T_eb699_row133_col0, #T_eb699_row134_col0, #T_eb699_row135_col0, #T_eb699_row136_col0, #T_eb699_row137_col0, #T_eb699_row138_col0, #T_eb699_row139_col0, #T_eb699_row140_col0, #T_eb699_row141_col0, #T_eb699_row142_col0, #T_eb699_row143_col0, #T_eb699_row144_col0, #T_eb699_row145_col0, #T_eb699_row146_col0, #T_eb699_row147_col0, #T_eb699_row148_col0, #T_eb699_row149_col0, #T_eb699_row150_col0, #T_eb699_row151_col0, #T_eb699_row152_col0, #T_eb699_row153_col0, #T_eb699_row154_col0, #T_eb699_row155_col0, #T_eb699_row156_col0, #T_eb699_row157_col0, #T_eb699_row158_col0, #T_eb699_row159_col0, #T_eb699_row160_col0, #T_eb699_row161_col0, #T_eb699_row162_col0, #T_eb699_row163_col0, #T_eb699_row164_col0, #T_eb699_row165_col0, #T_eb699_row166_col0, #T_eb699_row167_col0, #T_eb699_row168_col0, #T_eb699_row169_col0, #T_eb699_row170_col0, #T_eb699_row171_col0, #T_eb699_row172_col0, #T_eb699_row173_col0, #T_eb699_row174_col0, #T_eb699_row175_col0, #T_eb699_row176_col0, #T_eb699_row177_col0, #T_eb699_row178_col0, #T_eb699_row179_col0, #T_eb699_row180_col0, #T_eb699_row181_col0, #T_eb699_row182_col0, #T_eb699_row183_col0, #T_eb699_row184_col0, #T_eb699_row185_col0, #T_eb699_row186_co ...

# %% [markdown]
# ### -------- with two sample t test

# %%
p_val = pd.DataFrame(stats.ttest_ind(healty[0], ass[0])[1])
p_val.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_0d831_row0_col0, #T_0d831_row1_col0, #T_0d831_row2_col0, #T_0d831_row3_col0, #T_0d831_row4_col0, #T_0d831_row5_col0, #T_0d831_row6_col0, #T_0d831_row7_col0, #T_0d831_row8_col0, #T_0d831_row9_col0, #T_0d831_row10_col0, #T_0d831_row11_col0, #T_0d831_row12_col0, #T_0d831_row13_col0, #T_0d831_row14_col0, #T_0d831_row15_col0, #T_0d831_row16_col0, #T_0d831_row17_col0, #T_0d831_row18_col0, #T_0d831_row19_col0, #T_0d831_row20_col0, #T_0d831_row21_col0, #T_0d831_row22_col0, #T_0d831_row23_col0, #T_0d831_row24_col0, #T_0d831_row25_col0, #T_0d831_row26_col0, #T_0d831_row27_col0, #T_0d831_row28_col0, #T_0d831_row29_col0, #T_0d831_row30_col0, #T_0d831_row31_col0, #T_0d831_row32_col0, #T_0d831_row33_col0, #T_0d831_row34_col0, #T_0d831_row35_col0, #T_0d831_row36_col0, #T_0d831_row37_col0, #T_0d831_row38_col0, #T_0d831_row39_col0, #T_0d831_row40_col0, #T_0d831_row41_col0, #T_0d831_row42_col0, #T_0d831_row43_col0, #T_0d831_row44_col0, #T_0d831_row45_col0, #T_0d831_row46_col0, #T_0d831_row47_col0, #T_0d831_row48_col0, #T_0d831_row49_col0, #T_0d831_row50_col0, #T_0d831_row51_col0, #T_0d831_row52_col0, #T_0d831_row53_col0, #T_0d831_row54_col0, #T_0d831_row55_col0, #T_0d831_row56_col0, #T_0d831_row57_col0, #T_0d831_row58_col0, #T_0d831_row59_col0, #T_0d831_row60_col0, #T_0d831_row61_col0, #T_0d831_row62_col0, #T_0d831_row63_col0, #T_0d831_row64_col0, #T_0d831_row65_col0, #T_0d831_row66_col0, #T_0d831_row67_col0, #T_0d831_row68_col0, #T_0d831_row69_col0, #T_0d831_row70_col0, #T_0d831_row71_col0, #T_0d831_row72_col0, #T_0d831_row73_col0, #T_0d831_row74_col0, #T_0d831_row75_col0, #T_0d831_row76_col0, #T_0d831_row77_col0, #T_0d831_row78_col0, #T_0d831_row79_col0, #T_0d831_row80_col0, #T_0d831_row81_col0, #T_0d831_row82_col0, #T_0d831_row83_col0, #T_0d831_row84_col0, #T_0d831_row85_col0, #T_0d831_row86_col0, #T_0d831_row87_col0, #T_0d831_row88_col0, #T_0d831_row89_col0, #T_0d831_row90_col0, #T_0d831_row91_col0, #T_0d831_row92_col0, #T_0d831_row93_col0, #T_0d831_row94_col0, #T_0d831_row95_col0, #T_0d831_row96_col0, #T_0d831_row97_col0, #T_0d831_row98_col0, #T_0d831_row99_col0, #T_0d831_row100_col0, #T_0d831_row101_col0, #T_0d831_row102_col0, #T_0d831_row103_col0, #T_0d831_row104_col0, #T_0d831_row105_col0, #T_0d831_row106_col0, #T_0d831_row107_col0, #T_0d831_row108_col0, #T_0d831_row109_col0, #T_0d831_row110_col0, #T_0d831_row111_col0, #T_0d831_row112_col0, #T_0d831_row113_col0, #T_0d831_row114_col0, #T_0d831_row115_col0, #T_0d831_row116_col0, #T_0d831_row117_col0, #T_0d831_row118_col0, #T_0d831_row119_col0, #T_0d831_row120_col0, #T_0d831_row121_col0, #T_0d831_row122_col0, #T_0d831_row123_col0, #T_0d831_row124_col0, #T_0d831_row125_col0, #T_0d831_row126_col0, #T_0d831_row127_col0, #T_0d831_row128_col0, #T_0d831_row129_col0, #T_0d831_row130_col0, #T_0d831_row131_col0, #T_0d831_row132_col0, #T_0d831_row133_col0, #T_0d831_row134_col0, #T_0d831_row135_col0, #T_0d831_row136_col0, #T_0d831_row137_col0, #T_0d831_row138_col0, #T_0d831_row139_col0, #T_0d831_row140_col0, #T_0d831_row141_col0, #T_0d831_row142_col0, #T_0d831_row143_col0, #T_0d831_row144_col0, #T_0d831_row145_col0, #T_0d831_row146_col0, #T_0d831_row147_col0, #T_0d831_row148_col0, #T_0d831_row149_col0, #T_0d831_row150_col0, #T_0d831_row151_col0, #T_0d831_row152_col0, #T_0d831_row153_col0, #T_0d831_row154_col0, #T_0d831_row155_col0, #T_0d831_row156_col0, #T_0d831_row157_col0, #T_0d831_row158_col0, #T_0d831_row159_col0, #T_0d831_row160_col0, #T_0d831_row161_col0, #T_0d831_row162_col0, #T_0d831_row163_col0, #T_0d831_row164_col0, #T_0d831_row165_col0, #T_0d831_row166_col0, #T_0d831_row167_col0, #T_0d831_row168_col0, #T_0d831_row169_col0, #T_0d831_row170_col0, #T_0d831_row171_col0, #T_0d831_row172_col0, #T_0d831_row173_col0, #T_0d831_row174_col0, #T_0d831_row175_col0, #T_0d831_row176_col0, #T_0d831_row177_col0, #T_0d831_row178_col0, #T_0d831_row179_col0, #T_0d831_row180_col0, #T_0d831_row181_col0, #T_0d831_row182_col0, #T_0d831_row183_col0, #T_0d831_row184_col0, #T_0d831_row185_col0, #T_0d831_row186_co ...

# %% [markdown]
# ### y component

# %%
test_y = mannwhitneyu(healty[1], ass[1], use_continuity=False, alternative = 'two-sided')
df_stats_y = pd.DataFrame(test_y[1])
df_p_y = pd.DataFrame(test_y[1])
df_p_y
# Out:
#                  0
# 0     1.471893e-62
# 1     1.471893e-62
# 2     1.471893e-62
# 3     1.471893e-62
# 4     1.471893e-62
# ...            ...
# 2043  1.471893e-62
# 2044  1.471893e-62
# 2045  1.471893e-62
# 2046  1.471893e-62
# 2047  1.471893e-62
#
# [2048 rows x 1 columns]

# %%
df_p_y.style.apply(lambda x: ["background: yellow" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_9ec7c_row0_col0, #T_9ec7c_row1_col0, #T_9ec7c_row2_col0, #T_9ec7c_row3_col0, #T_9ec7c_row4_col0, #T_9ec7c_row5_col0, #T_9ec7c_row6_col0, #T_9ec7c_row7_col0, #T_9ec7c_row8_col0, #T_9ec7c_row9_col0, #T_9ec7c_row10_col0, #T_9ec7c_row11_col0, #T_9ec7c_row12_col0, #T_9ec7c_row13_col0, #T_9ec7c_row14_col0, #T_9ec7c_row15_col0, #T_9ec7c_row16_col0, #T_9ec7c_row17_col0, #T_9ec7c_row18_col0, #T_9ec7c_row19_col0, #T_9ec7c_row20_col0, #T_9ec7c_row21_col0, #T_9ec7c_row22_col0, #T_9ec7c_row23_col0, #T_9ec7c_row24_col0, #T_9ec7c_row25_col0, #T_9ec7c_row26_col0, #T_9ec7c_row27_col0, #T_9ec7c_row28_col0, #T_9ec7c_row29_col0, #T_9ec7c_row30_col0, #T_9ec7c_row31_col0, #T_9ec7c_row32_col0, #T_9ec7c_row33_col0, #T_9ec7c_row34_col0, #T_9ec7c_row35_col0, #T_9ec7c_row36_col0, #T_9ec7c_row37_col0, #T_9ec7c_row38_col0, #T_9ec7c_row39_col0, #T_9ec7c_row40_col0, #T_9ec7c_row41_col0, #T_9ec7c_row42_col0, #T_9ec7c_row43_col0, #T_9ec7c_row44_col0, #T_9ec7c_row45_col0, #T_9ec7c_row46_col0, #T_9ec7c_row47_col0, #T_9ec7c_row48_col0, #T_9ec7c_row49_col0, #T_9ec7c_row50_col0, #T_9ec7c_row51_col0, #T_9ec7c_row52_col0, #T_9ec7c_row53_col0, #T_9ec7c_row54_col0, #T_9ec7c_row55_col0, #T_9ec7c_row56_col0, #T_9ec7c_row57_col0, #T_9ec7c_row58_col0, #T_9ec7c_row59_col0, #T_9ec7c_row60_col0, #T_9ec7c_row61_col0, #T_9ec7c_row62_col0, #T_9ec7c_row63_col0, #T_9ec7c_row64_col0, #T_9ec7c_row65_col0, #T_9ec7c_row66_col0, #T_9ec7c_row67_col0, #T_9ec7c_row68_col0, #T_9ec7c_row69_col0, #T_9ec7c_row70_col0, #T_9ec7c_row71_col0, #T_9ec7c_row72_col0, #T_9ec7c_row73_col0, #T_9ec7c_row74_col0, #T_9ec7c_row75_col0, #T_9ec7c_row76_col0, #T_9ec7c_row77_col0, #T_9ec7c_row78_col0, #T_9ec7c_row79_col0, #T_9ec7c_row80_col0, #T_9ec7c_row81_col0, #T_9ec7c_row82_col0, #T_9ec7c_row83_col0, #T_9ec7c_row84_col0, #T_9ec7c_row85_col0, #T_9ec7c_row86_col0, #T_9ec7c_row87_col0, #T_9ec7c_row88_col0, #T_9ec7c_row89_col0, #T_9ec7c_row90_col0, #T_9ec7c_row91_col0, #T_9ec7c_row92_col0, #T_9ec7c_row93_col0, #T_9ec7c_row94_col0, #T_9ec7c_row95_col0, #T_9ec7c_row96_col0, #T_9ec7c_row97_col0, #T_9ec7c_row98_col0, #T_9ec7c_row99_col0, #T_9ec7c_row100_col0, #T_9ec7c_row101_col0, #T_9ec7c_row102_col0, #T_9ec7c_row103_col0, #T_9ec7c_row104_col0, #T_9ec7c_row105_col0, #T_9ec7c_row106_col0, #T_9ec7c_row107_col0, #T_9ec7c_row108_col0, #T_9ec7c_row109_col0, #T_9ec7c_row110_col0, #T_9ec7c_row111_col0, #T_9ec7c_row112_col0, #T_9ec7c_row113_col0, #T_9ec7c_row114_col0, #T_9ec7c_row115_col0, #T_9ec7c_row116_col0, #T_9ec7c_row117_col0, #T_9ec7c_row118_col0, #T_9ec7c_row119_col0, #T_9ec7c_row120_col0, #T_9ec7c_row121_col0, #T_9ec7c_row122_col0, #T_9ec7c_row123_col0, #T_9ec7c_row124_col0, #T_9ec7c_row125_col0, #T_9ec7c_row126_col0, #T_9ec7c_row127_col0, #T_9ec7c_row128_col0, #T_9ec7c_row129_col0, #T_9ec7c_row130_col0, #T_9ec7c_row131_col0, #T_9ec7c_row132_col0, #T_9ec7c_row133_col0, #T_9ec7c_row134_col0, #T_9ec7c_row135_col0, #T_9ec7c_row136_col0, #T_9ec7c_row137_col0, #T_9ec7c_row138_col0, #T_9ec7c_row139_col0, #T_9ec7c_row140_col0, #T_9ec7c_row141_col0, #T_9ec7c_row142_col0, #T_9ec7c_row143_col0, #T_9ec7c_row144_col0, #T_9ec7c_row145_col0, #T_9ec7c_row146_col0, #T_9ec7c_row147_col0, #T_9ec7c_row148_col0, #T_9ec7c_row149_col0, #T_9ec7c_row150_col0, #T_9ec7c_row151_col0, #T_9ec7c_row152_col0, #T_9ec7c_row153_col0, #T_9ec7c_row154_col0, #T_9ec7c_row155_col0, #T_9ec7c_row156_col0, #T_9ec7c_row157_col0, #T_9ec7c_row158_col0, #T_9ec7c_row159_col0, #T_9ec7c_row160_col0, #T_9ec7c_row161_col0, #T_9ec7c_row162_col0, #T_9ec7c_row163_col0, #T_9ec7c_row164_col0, #T_9ec7c_row165_col0, #T_9ec7c_row166_col0, #T_9ec7c_row167_col0, #T_9ec7c_row168_col0, #T_9ec7c_row169_col0, #T_9ec7c_row170_col0, #T_9ec7c_row171_col0, #T_9ec7c_row172_col0, #T_9ec7c_row173_col0, #T_9ec7c_row174_col0, #T_9ec7c_row175_col0, #T_9ec7c_row176_col0, #T_9ec7c_row177_col0, #T_9ec7c_row178_col0, #T_9ec7c_row179_col0, #T_9ec7c_row180_col0, #T_9ec7c_row181_col0, #T_9ec7c_row182_col0, #T_9ec7c_row183_col0, #T_9ec7c_row184_col0, #T_9ec7c_row185_col0, #T_9ec7c_row186_co ...

# %% [markdown]
# ### --------- with two sample t test

# %%
p_val_y = pd.DataFrame(stats.ttest_ind(healty[1], ass[1])[1])
p_val_y.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_e816a_row0_col0, #T_e816a_row1_col0, #T_e816a_row2_col0, #T_e816a_row3_col0, #T_e816a_row4_col0, #T_e816a_row5_col0, #T_e816a_row6_col0, #T_e816a_row7_col0, #T_e816a_row8_col0, #T_e816a_row9_col0, #T_e816a_row10_col0, #T_e816a_row11_col0, #T_e816a_row12_col0, #T_e816a_row13_col0, #T_e816a_row14_col0, #T_e816a_row15_col0, #T_e816a_row16_col0, #T_e816a_row17_col0, #T_e816a_row18_col0, #T_e816a_row19_col0, #T_e816a_row20_col0, #T_e816a_row21_col0, #T_e816a_row22_col0, #T_e816a_row23_col0, #T_e816a_row24_col0, #T_e816a_row25_col0, #T_e816a_row26_col0, #T_e816a_row27_col0, #T_e816a_row28_col0, #T_e816a_row29_col0, #T_e816a_row30_col0, #T_e816a_row31_col0, #T_e816a_row32_col0, #T_e816a_row33_col0, #T_e816a_row34_col0, #T_e816a_row35_col0, #T_e816a_row36_col0, #T_e816a_row37_col0, #T_e816a_row38_col0, #T_e816a_row39_col0, #T_e816a_row40_col0, #T_e816a_row41_col0, #T_e816a_row42_col0, #T_e816a_row43_col0, #T_e816a_row44_col0, #T_e816a_row45_col0, #T_e816a_row46_col0, #T_e816a_row47_col0, #T_e816a_row48_col0, #T_e816a_row49_col0, #T_e816a_row50_col0, #T_e816a_row51_col0, #T_e816a_row52_col0, #T_e816a_row53_col0, #T_e816a_row54_col0, #T_e816a_row55_col0, #T_e816a_row56_col0, #T_e816a_row57_col0, #T_e816a_row58_col0, #T_e816a_row59_col0, #T_e816a_row60_col0, #T_e816a_row61_col0, #T_e816a_row62_col0, #T_e816a_row63_col0, #T_e816a_row64_col0, #T_e816a_row65_col0, #T_e816a_row66_col0, #T_e816a_row67_col0, #T_e816a_row68_col0, #T_e816a_row69_col0, #T_e816a_row70_col0, #T_e816a_row71_col0, #T_e816a_row72_col0, #T_e816a_row73_col0, #T_e816a_row74_col0, #T_e816a_row75_col0, #T_e816a_row76_col0, #T_e816a_row77_col0, #T_e816a_row78_col0, #T_e816a_row79_col0, #T_e816a_row80_col0, #T_e816a_row81_col0, #T_e816a_row82_col0, #T_e816a_row83_col0, #T_e816a_row84_col0, #T_e816a_row85_col0, #T_e816a_row86_col0, #T_e816a_row87_col0, #T_e816a_row88_col0, #T_e816a_row89_col0, #T_e816a_row90_col0, #T_e816a_row91_col0, #T_e816a_row92_col0, #T_e816a_row93_col0, #T_e816a_row94_col0, #T_e816a_row95_col0, #T_e816a_row96_col0, #T_e816a_row97_col0, #T_e816a_row98_col0, #T_e816a_row99_col0, #T_e816a_row100_col0, #T_e816a_row101_col0, #T_e816a_row102_col0, #T_e816a_row103_col0, #T_e816a_row104_col0, #T_e816a_row105_col0, #T_e816a_row106_col0, #T_e816a_row107_col0, #T_e816a_row108_col0, #T_e816a_row109_col0, #T_e816a_row110_col0, #T_e816a_row111_col0, #T_e816a_row112_col0, #T_e816a_row113_col0, #T_e816a_row114_col0, #T_e816a_row115_col0, #T_e816a_row116_col0, #T_e816a_row117_col0, #T_e816a_row118_col0, #T_e816a_row119_col0, #T_e816a_row120_col0, #T_e816a_row121_col0, #T_e816a_row122_col0, #T_e816a_row123_col0, #T_e816a_row124_col0, #T_e816a_row125_col0, #T_e816a_row126_col0, #T_e816a_row127_col0, #T_e816a_row128_col0, #T_e816a_row129_col0, #T_e816a_row130_col0, #T_e816a_row131_col0, #T_e816a_row132_col0, #T_e816a_row133_col0, #T_e816a_row134_col0, #T_e816a_row135_col0, #T_e816a_row136_col0, #T_e816a_row137_col0, #T_e816a_row138_col0, #T_e816a_row139_col0, #T_e816a_row140_col0, #T_e816a_row141_col0, #T_e816a_row142_col0, #T_e816a_row143_col0, #T_e816a_row144_col0, #T_e816a_row145_col0, #T_e816a_row146_col0, #T_e816a_row147_col0, #T_e816a_row148_col0, #T_e816a_row149_col0, #T_e816a_row150_col0, #T_e816a_row151_col0, #T_e816a_row152_col0, #T_e816a_row153_col0, #T_e816a_row154_col0, #T_e816a_row155_col0, #T_e816a_row156_col0, #T_e816a_row157_col0, #T_e816a_row158_col0, #T_e816a_row159_col0, #T_e816a_row160_col0, #T_e816a_row161_col0, #T_e816a_row162_col0, #T_e816a_row163_col0, #T_e816a_row164_col0, #T_e816a_row165_col0, #T_e816a_row166_col0, #T_e816a_row167_col0, #T_e816a_row168_col0, #T_e816a_row169_col0, #T_e816a_row170_col0, #T_e816a_row171_col0, #T_e816a_row172_col0, #T_e816a_row173_col0, #T_e816a_row174_col0, #T_e816a_row175_col0, #T_e816a_row176_col0, #T_e816a_row177_col0, #T_e816a_row178_col0, #T_e816a_row179_col0, #T_e816a_row180_col0, #T_e816a_row181_col0, #T_e816a_row182_col0, #T_e816a_row183_col0, #T_e816a_row184_col0, #T_e816a_row185_col0, #T_e816a_row186_co ...

# %% [markdown]
# ### z component

# %%
test_z = mannwhitneyu(healty[2], ass[2], use_continuity=False, alternative = 'two-sided')
df_stats_z = pd.DataFrame(test_z[1])
df_p_z = pd.DataFrame(test_z[1])
df_p_z
# Out:
#                  0
# 0     1.471893e-62
# 1     1.471893e-62
# 2     1.471893e-62
# 3     1.471893e-62
# 4     1.471893e-62
# ...            ...
# 2043  1.471893e-62
# 2044  1.471893e-62
# 2045  1.471893e-62
# 2046  1.471893e-62
# 2047  1.471893e-62
#
# [2048 rows x 1 columns]

# %%
df_p_z.style.apply(lambda x: ["background: yellow" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_11e6e_row0_col0, #T_11e6e_row1_col0, #T_11e6e_row2_col0, #T_11e6e_row3_col0, #T_11e6e_row4_col0, #T_11e6e_row5_col0, #T_11e6e_row6_col0, #T_11e6e_row7_col0, #T_11e6e_row8_col0, #T_11e6e_row9_col0, #T_11e6e_row10_col0, #T_11e6e_row11_col0, #T_11e6e_row12_col0, #T_11e6e_row13_col0, #T_11e6e_row14_col0, #T_11e6e_row15_col0, #T_11e6e_row16_col0, #T_11e6e_row17_col0, #T_11e6e_row18_col0, #T_11e6e_row19_col0, #T_11e6e_row20_col0, #T_11e6e_row21_col0, #T_11e6e_row22_col0, #T_11e6e_row23_col0, #T_11e6e_row24_col0, #T_11e6e_row25_col0, #T_11e6e_row26_col0, #T_11e6e_row27_col0, #T_11e6e_row28_col0, #T_11e6e_row29_col0, #T_11e6e_row30_col0, #T_11e6e_row31_col0, #T_11e6e_row32_col0, #T_11e6e_row33_col0, #T_11e6e_row34_col0, #T_11e6e_row35_col0, #T_11e6e_row36_col0, #T_11e6e_row37_col0, #T_11e6e_row38_col0, #T_11e6e_row39_col0, #T_11e6e_row40_col0, #T_11e6e_row41_col0, #T_11e6e_row42_col0, #T_11e6e_row43_col0, #T_11e6e_row44_col0, #T_11e6e_row45_col0, #T_11e6e_row46_col0, #T_11e6e_row47_col0, #T_11e6e_row48_col0, #T_11e6e_row49_col0, #T_11e6e_row50_col0, #T_11e6e_row51_col0, #T_11e6e_row52_col0, #T_11e6e_row53_col0, #T_11e6e_row54_col0, #T_11e6e_row55_col0, #T_11e6e_row56_col0, #T_11e6e_row57_col0, #T_11e6e_row58_col0, #T_11e6e_row59_col0, #T_11e6e_row60_col0, #T_11e6e_row61_col0, #T_11e6e_row62_col0, #T_11e6e_row63_col0, #T_11e6e_row64_col0, #T_11e6e_row65_col0, #T_11e6e_row66_col0, #T_11e6e_row67_col0, #T_11e6e_row68_col0, #T_11e6e_row69_col0, #T_11e6e_row70_col0, #T_11e6e_row71_col0, #T_11e6e_row72_col0, #T_11e6e_row73_col0, #T_11e6e_row74_col0, #T_11e6e_row75_col0, #T_11e6e_row76_col0, #T_11e6e_row77_col0, #T_11e6e_row78_col0, #T_11e6e_row79_col0, #T_11e6e_row80_col0, #T_11e6e_row81_col0, #T_11e6e_row82_col0, #T_11e6e_row83_col0, #T_11e6e_row84_col0, #T_11e6e_row85_col0, #T_11e6e_row86_col0, #T_11e6e_row87_col0, #T_11e6e_row88_col0, #T_11e6e_row89_col0, #T_11e6e_row90_col0, #T_11e6e_row91_col0, #T_11e6e_row92_col0, #T_11e6e_row93_col0, #T_11e6e_row94_col0, #T_11e6e_row95_col0, #T_11e6e_row96_col0, #T_11e6e_row97_col0, #T_11e6e_row98_col0, #T_11e6e_row99_col0, #T_11e6e_row100_col0, #T_11e6e_row101_col0, #T_11e6e_row102_col0, #T_11e6e_row103_col0, #T_11e6e_row104_col0, #T_11e6e_row105_col0, #T_11e6e_row106_col0, #T_11e6e_row107_col0, #T_11e6e_row108_col0, #T_11e6e_row109_col0, #T_11e6e_row110_col0, #T_11e6e_row111_col0, #T_11e6e_row112_col0, #T_11e6e_row113_col0, #T_11e6e_row114_col0, #T_11e6e_row115_col0, #T_11e6e_row116_col0, #T_11e6e_row117_col0, #T_11e6e_row118_col0, #T_11e6e_row119_col0, #T_11e6e_row120_col0, #T_11e6e_row121_col0, #T_11e6e_row122_col0, #T_11e6e_row123_col0, #T_11e6e_row124_col0, #T_11e6e_row125_col0, #T_11e6e_row126_col0, #T_11e6e_row127_col0, #T_11e6e_row128_col0, #T_11e6e_row129_col0, #T_11e6e_row130_col0, #T_11e6e_row131_col0, #T_11e6e_row132_col0, #T_11e6e_row133_col0, #T_11e6e_row134_col0, #T_11e6e_row135_col0, #T_11e6e_row136_col0, #T_11e6e_row137_col0, #T_11e6e_row138_col0, #T_11e6e_row139_col0, #T_11e6e_row140_col0, #T_11e6e_row141_col0, #T_11e6e_row142_col0, #T_11e6e_row143_col0, #T_11e6e_row144_col0, #T_11e6e_row145_col0, #T_11e6e_row146_col0, #T_11e6e_row147_col0, #T_11e6e_row148_col0, #T_11e6e_row149_col0, #T_11e6e_row150_col0, #T_11e6e_row151_col0, #T_11e6e_row152_col0, #T_11e6e_row153_col0, #T_11e6e_row154_col0, #T_11e6e_row155_col0, #T_11e6e_row156_col0, #T_11e6e_row157_col0, #T_11e6e_row158_col0, #T_11e6e_row159_col0, #T_11e6e_row160_col0, #T_11e6e_row161_col0, #T_11e6e_row162_col0, #T_11e6e_row163_col0, #T_11e6e_row164_col0, #T_11e6e_row165_col0, #T_11e6e_row166_col0, #T_11e6e_row167_col0, #T_11e6e_row168_col0, #T_11e6e_row169_col0, #T_11e6e_row170_col0, #T_11e6e_row171_col0, #T_11e6e_row172_col0, #T_11e6e_row173_col0, #T_11e6e_row174_col0, #T_11e6e_row175_col0, #T_11e6e_row176_col0, #T_11e6e_row177_col0, #T_11e6e_row178_col0, #T_11e6e_row179_col0, #T_11e6e_row180_col0, #T_11e6e_row181_col0, #T_11e6e_row182_col0, #T_11e6e_row183_col0, #T_11e6e_row184_col0, #T_11e6e_row185_col0, #T_11e6e_row186_co ...

# %% [markdown]
# ### --------- with two sample t test

# %%
p_val_y = pd.DataFrame(stats.ttest_ind(healty[1], ass[1])[1])
p_val_y.style.apply(lambda x: ["background: pink" if v < 0.05 else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# #T_28697_row0_col0, #T_28697_row1_col0, #T_28697_row2_col0, #T_28697_row3_col0, #T_28697_row4_col0, #T_28697_row5_col0, #T_28697_row6_col0, #T_28697_row7_col0, #T_28697_row8_col0, #T_28697_row9_col0, #T_28697_row10_col0, #T_28697_row11_col0, #T_28697_row12_col0, #T_28697_row13_col0, #T_28697_row14_col0, #T_28697_row15_col0, #T_28697_row16_col0, #T_28697_row17_col0, #T_28697_row18_col0, #T_28697_row19_col0, #T_28697_row20_col0, #T_28697_row21_col0, #T_28697_row22_col0, #T_28697_row23_col0, #T_28697_row24_col0, #T_28697_row25_col0, #T_28697_row26_col0, #T_28697_row27_col0, #T_28697_row28_col0, #T_28697_row29_col0, #T_28697_row30_col0, #T_28697_row31_col0, #T_28697_row32_col0, #T_28697_row33_col0, #T_28697_row34_col0, #T_28697_row35_col0, #T_28697_row36_col0, #T_28697_row37_col0, #T_28697_row38_col0, #T_28697_row39_col0, #T_28697_row40_col0, #T_28697_row41_col0, #T_28697_row42_col0, #T_28697_row43_col0, #T_28697_row44_col0, #T_28697_row45_col0, #T_28697_row46_col0, #T_28697_row47_col0, #T_28697_row48_col0, #T_28697_row49_col0, #T_28697_row50_col0, #T_28697_row51_col0, #T_28697_row52_col0, #T_28697_row53_col0, #T_28697_row54_col0, #T_28697_row55_col0, #T_28697_row56_col0, #T_28697_row57_col0, #T_28697_row58_col0, #T_28697_row59_col0, #T_28697_row60_col0, #T_28697_row61_col0, #T_28697_row62_col0, #T_28697_row63_col0, #T_28697_row64_col0, #T_28697_row65_col0, #T_28697_row66_col0, #T_28697_row67_col0, #T_28697_row68_col0, #T_28697_row69_col0, #T_28697_row70_col0, #T_28697_row71_col0, #T_28697_row72_col0, #T_28697_row73_col0, #T_28697_row74_col0, #T_28697_row75_col0, #T_28697_row76_col0, #T_28697_row77_col0, #T_28697_row78_col0, #T_28697_row79_col0, #T_28697_row80_col0, #T_28697_row81_col0, #T_28697_row82_col0, #T_28697_row83_col0, #T_28697_row84_col0, #T_28697_row85_col0, #T_28697_row86_col0, #T_28697_row87_col0, #T_28697_row88_col0, #T_28697_row89_col0, #T_28697_row90_col0, #T_28697_row91_col0, #T_28697_row92_col0, #T_28697_row93_col0, #T_28697_row94_col0, #T_28697_row95_col0, #T_28697_row96_col0, #T_28697_row97_col0, #T_28697_row98_col0, #T_28697_row99_col0, #T_28697_row100_col0, #T_28697_row101_col0, #T_28697_row102_col0, #T_28697_row103_col0, #T_28697_row104_col0, #T_28697_row105_col0, #T_28697_row106_col0, #T_28697_row107_col0, #T_28697_row108_col0, #T_28697_row109_col0, #T_28697_row110_col0, #T_28697_row111_col0, #T_28697_row112_col0, #T_28697_row113_col0, #T_28697_row114_col0, #T_28697_row115_col0, #T_28697_row116_col0, #T_28697_row117_col0, #T_28697_row118_col0, #T_28697_row119_col0, #T_28697_row120_col0, #T_28697_row121_col0, #T_28697_row122_col0, #T_28697_row123_col0, #T_28697_row124_col0, #T_28697_row125_col0, #T_28697_row126_col0, #T_28697_row127_col0, #T_28697_row128_col0, #T_28697_row129_col0, #T_28697_row130_col0, #T_28697_row131_col0, #T_28697_row132_col0, #T_28697_row133_col0, #T_28697_row134_col0, #T_28697_row135_col0, #T_28697_row136_col0, #T_28697_row137_col0, #T_28697_row138_col0, #T_28697_row139_col0, #T_28697_row140_col0, #T_28697_row141_col0, #T_28697_row142_col0, #T_28697_row143_col0, #T_28697_row144_col0, #T_28697_row145_col0, #T_28697_row146_col0, #T_28697_row147_col0, #T_28697_row148_col0, #T_28697_row149_col0, #T_28697_row150_col0, #T_28697_row151_col0, #T_28697_row152_col0, #T_28697_row153_col0, #T_28697_row154_col0, #T_28697_row155_col0, #T_28697_row156_col0, #T_28697_row157_col0, #T_28697_row158_col0, #T_28697_row159_col0, #T_28697_row160_col0, #T_28697_row161_col0, #T_28697_row162_col0, #T_28697_row163_col0, #T_28697_row164_col0, #T_28697_row165_col0, #T_28697_row166_col0, #T_28697_row167_col0, #T_28697_row168_col0, #T_28697_row169_col0, #T_28697_row170_col0, #T_28697_row171_col0, #T_28697_row172_col0, #T_28697_row173_col0, #T_28697_row174_col0, #T_28697_row175_col0, #T_28697_row176_col0, #T_28697_row177_col0, #T_28697_row178_col0, #T_28697_row179_col0, #T_28697_row180_col0, #T_28697_row181_col0, #T_28697_row182_col0, #T_28697_row183_col0, #T_28697_row184_col0, #T_28697_row185_col0, #T_28697_row186_co ...
