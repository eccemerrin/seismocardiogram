# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
csv_path = "/Users/ecem/Desktop/csv of scgs"

# %%
spec = pd.read_csv(csv_path + '/four-diseases-spectogram_coef.csv', index_col = 0)
#spec  #uncomment to see dataframe

zcr = pd.read_csv(csv_path + '/four-disease-zcrs.csv', index_col = 0)

temp = pd.read_csv(csv_path + '/four-disease-tempogram.csv', index_col = 0)

chro = pd.read_csv(csv_path + '/four-disease-chromogram.csv', index_col = 0)

w_lvl0 = pd.read_csv(csv_path + '/four-disease-wavelet-lvl0-coef.csv', index_col = 0)
w_lvl0 = w_lvl0.reset_index(drop=True)
#w_lvl0  #uncomment to see dataframe

#wavelet =pd.read_csv(csv_path + '/p-value-selected-four-disease-mean-wavelet.csv', index_col = 0)

# %%
w_lvl0
# Out:
#        lvl0_x0   lvl0_x1   lvl0_x2   lvl0_x3   lvl0_x4   lvl0_x5   lvl0_x6  \
# 0    -0.503078 -0.508493 -0.495124 -0.461686 -0.327573 -0.463505 -0.319357
# 1    -0.337088 -0.358658 -0.344212 -0.297174 -0.193528 -0.346729 -0.177544
# 2    -0.382271 -0.409044 -0.397055 -0.353910 -0.297396 -0.389712 -0.234055
# 3     0.071162  0.089320  0.064081 -0.037265 -0.353574 -0.289820 -0.397483
# 4    -0.790181 -0.790978 -0.778167 -0.723883 -0.509830 -0.586515 -0.283325
# ...        ...       ...       ...       ...       ...       ...       ...
# 2387  0.254162  0.256369  0.261570  0.288534  0.391812  0.492755  0.414114
# 2388  0.349622  0.321284  0.310296  0.278119  0.003263 -0.149820 -0.205826
# 2389 -0.163857 -0.138495 -0.157529 -0.233442 -0.414839 -0.340551 -0.398183
# 2390 -0.383882 -0.363848 -0.364389 -0.366114 -0.272939  0.017750  0.177799
# 2391  0.058736  0.077297  0.081598  0.094160  0.236699  0.330723  0.371080
#
# ...

# %%
spec
# Out:
#       index   freq_x0   freq_y0   freq_z0   freq_x1   freq_y1   freq_z1  \
# 0         0  0.000462  0.000658  0.000667  0.000676  0.000683  0.000685
# 1         0  0.000359  0.000513  0.000522  0.000531  0.000538  0.000542
# 2         0  0.000467  0.000674  0.000698  0.000725  0.000752  0.000779
# 3         0  0.000422  0.000606  0.000621  0.000636  0.000647  0.000654
# 4         0  0.000379  0.000540  0.000547  0.000553  0.000556  0.000557
# ...     ...       ...       ...       ...       ...       ...       ...
# 2387      0  0.000161  0.000230  0.000234  0.000237  0.000240  0.000243
# 2388      0  0.000140  0.000202  0.000208  0.000214  0.000221  0.000227
# 2389      0  0.000153  0.000218  0.000222  0.000226  0.000230  0.000234
# 2390      0  0.000153  0.000221  0.000230  0.000242  0.000255  0.000269
# 2391      0  0.000073  0.000105  0.000106  0.000106  0.000106  0.000105
#
#        freq_x2   freq_y2   freq_z2  ...  freq_z2044  freq_x2045  freq_y2045  \
# ...

# %%
zcr
# Out:
#         zcr_x0    zcr_y0    zcr_z0    zcr_x1    zcr_y1    zcr_z1    zcr_x2  \
# 0     0.014648  0.027344  0.041016  0.058594  0.048828  0.036133  0.032227
# 1     0.049805  0.071289  0.089844  0.088867  0.063477  0.041992  0.062500
# 2     0.033203  0.047852  0.065430  0.060547  0.046875  0.032227  0.059570
# 3     0.024414  0.040527  0.049805  0.041016  0.029297  0.012695  0.069336
# 4     0.018066  0.035156  0.052734  0.069824  0.059570  0.042969  0.055664
# ...        ...       ...       ...       ...       ...       ...       ...
# 2387  0.018066  0.035645  0.038574  0.042480  0.039062  0.021973  0.025879
# 2388  0.016602  0.023926  0.039062  0.036133  0.029785  0.022461  0.038086
# 2389  0.011719  0.025879  0.036133  0.030762  0.024414  0.010254  0.034180
# 2390  0.027344  0.032715  0.043945  0.039062  0.025879  0.020508  0.031250
# 2391  0.020996  0.039551  0.039551  0.092285  0.082520  0.063965  0.034180
#
# ...

# %%
temp
# Out:
#       tempogram_x0  tempogram_y0  tempogram_z0  tempogram_x1  tempogram_y1  \
# 0              1.0      0.680887      0.545814      0.492319      0.467303
# 1              1.0      0.685560      0.567166      0.543523      0.534272
# 2              1.0      0.723711      0.617749      0.601873      0.615645
# 3              1.0      0.613598      0.464171      0.427132      0.411996
# 4              1.0      0.743774      0.663251      0.633607      0.617163
# ...            ...           ...           ...           ...           ...
# 2387           1.0      0.784905      0.719192      0.705264      0.699543
# 2388           1.0      0.766976      0.695145      0.665635      0.655031
# 2389           1.0      0.834884      0.779556      0.776158      0.787031
# 2390           1.0      0.796099      0.731806      0.724479      0.729266
# 2391           1.0      0.175541      0.010801      0.003006      0.000395
#
# ...

# %%
chro
# Out:
#            C_x       C_y       C_z      C♯_x      C♯_y      C♯_z       D_x  \
# 0     0.800277  0.762100  0.743509  0.828520  0.725288  0.676100  0.622803
# 1     0.788901  0.664045  0.601065  0.673538  0.576668  0.579724  0.703581
# 2     0.768100  0.697642  0.790078  0.845064  0.663615  0.639449  0.574114
# 3     0.745292  0.654161  0.667090  0.727542  0.672035  0.603927  0.589418
# 4     0.814436  0.727435  0.704867  0.714515  0.682958  0.580415  0.660723
# ...        ...       ...       ...       ...       ...       ...       ...
# 2387  0.736128  0.491858  0.524962  0.510015  0.566563  0.714840  0.598320
# 2388  0.816455  0.472397  0.482912  0.515888  0.616837  0.604521  0.644965
# 2389  0.719136  0.459924  0.515967  0.562621  0.582247  0.713227  0.708858
# 2390  0.858093  0.585064  0.583672  0.603348  0.657138  0.791714  0.818522
# 2391  0.837431  0.341767  0.337754  0.431191  0.640613  0.693439  0.676990
#
# ...

# %%
df = pd.concat([spec, w_lvl0], axis=1)
df = pd.concat([df,zcr], axis=1)
df = pd.concat([df, chro], axis=1)
df = pd.concat([df, temp], axis=1)

# %%
df
# Out:
#       index   freq_x0   freq_y0   freq_z0   freq_x1   freq_y1   freq_z1  \
# 0         0  0.000462  0.000658  0.000667  0.000676  0.000683  0.000685
# 1         0  0.000359  0.000513  0.000522  0.000531  0.000538  0.000542
# 2         0  0.000467  0.000674  0.000698  0.000725  0.000752  0.000779
# 3         0  0.000422  0.000606  0.000621  0.000636  0.000647  0.000654
# 4         0  0.000379  0.000540  0.000547  0.000553  0.000556  0.000557
# ...     ...       ...       ...       ...       ...       ...       ...
# 2387      0  0.000161  0.000230  0.000234  0.000237  0.000240  0.000243
# 2388      0  0.000140  0.000202  0.000208  0.000214  0.000221  0.000227
# 2389      0  0.000153  0.000218  0.000222  0.000226  0.000230  0.000234
# 2390      0  0.000153  0.000221  0.000230  0.000242  0.000255  0.000269
# 2391      0  0.000073  0.000105  0.000106  0.000106  0.000106  0.000105
#
#        freq_x2   freq_y2   freq_z2  ...  tempogram_z380  tempogram_x381  \
# ...

# %%
#df.to_csv(csv_path + '/four-diseases-all.csv')
